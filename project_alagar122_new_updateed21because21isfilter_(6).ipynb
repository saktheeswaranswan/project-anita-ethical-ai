# %% [markdown]
# <a href="https://colab.research.google.com/github/saktheeswaranswan/project-anita-ethical-ai/blob/main/project_alagar122_new_updateed21because21isfilter_(6).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15864, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 15864 (delta 10), reused 18 (delta 8), pack-reused 15833 (from 1)
# Receiving objects: 100% (15864/15864), 14.44 MiB | 15.25 MiB/s, done.
# Resolving deltas: 100% (10676/10676), done.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="PMqWkCWwzu25tXIe90bo")
project = rf.workspace("data-zygje").project("sajam")
version = project.version(10)
dataset = version.download("darknet")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.48-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from roboflow) (2024.8.30)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.7)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (10.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.2.3)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.2)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.54.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.4.0)
# Downloading roboflow-1.1.48-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 2.6 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.2 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: filetype, python-dotenv, idna, requests-toolbelt, roboflow
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# Successfully installed filetype-1.2.0 idna-3.7 python-dotenv-1.0.1 requests-toolbelt-1.0.0 roboflow-1.1.48
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in sajam-10 to darknet:: 100%|██████████| 37377/37377 [00:01<00:00, 33216.58it/s]
# Extracting Dataset Version Zip to sajam-10 in darknet:: 100%|██████████| 2000/2000 [00:00<00:00, 4507.85it/s]

# %%
# %cd /content/sajam-10
# Out:
# /content/sajam-10

# %%
# !mv /content/sajam-10/valid/*.jpg /content/alagar-bot-veeran
# Out:
# mv: cannot stat '/content/sajam-10/valid/*.jpg': No such file or directory

# %%
import glob, os


dataset_path = '/content/alagar-bot-veeran'

# Percentage of images to be used for the test set
percentage_test = 12;

# Create and/or truncate train.txt and test.txt
file_train = open('train.txt', 'w')
file_test = open('test.txt', 'w')

# Populate train.txt and test.txt
counter = 1
index_test = round(100 / percentage_test)
for pathAndFilename in glob.iglob(os.path.join(dataset_path, "*.jpg")):
    title, ext = os.path.splitext(os.path.basename(pathAndFilename))

    if counter == index_test+1:
        counter = 1
        file_test.write(dataset_path + "/" + title + '.jpg' + "\n")
    else:
        file_train.write(dataset_path + "/" + title + '.jpg' + "\n")
        counter = counter + 1

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	image_yolov3.sh        obj	    vcpkg.json
# backup		darknet_images.py	image_yolov4.sh        package.xml  video_yolov3.sh
# build		darknet.py		include		       README.md    video_yolov4.sh
# build.ps1	darknet_video.py	json_mjpeg_streams.sh  results	    yolov7-tiny.weights
# cfg		data			LICENSE		       scripts
# cmake		docker-compose.yml	Makefile	       src
# CMakeLists.txt	Dockerfile.cpu		net_cam_v3.sh	       test.txt
# darknet		Dockerfile.gpu		net_cam_v4.sh	       train.txt

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:945:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   945 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1443:14: warning: unused variable ‘buff’ [-Wunused-variable]
#  1443 |         char buff[100];
#       |              ^~~~
# ./src/image_opencv.cpp:1419:9: warning: unused variable ‘it_tb_res’ [-Wunused-variable]
#  1419 |     int it_tb_res = cv::createTrackbar(it_trackbar_name, window_name, &it_trackbar_value, 1000);
#       |         ^~~~~~~~~
# ./src/image_opencv.cpp:1423:9: warning: unused variable ‘lr_tb_res’ [-Wunused-variable]
#  1423 |     int lr_tb_res = cv::createTrackbar(lr_trackbar_name, window_name, &lr_trackbar_value, 20);
#       |         ^~~~~~~~~
# ./src/image_opencv.cpp:1427:9: warning: unused variable ‘cl_tb_res’ [-Wunused-variable]
#  1427 |     int cl_tb_res = cv::createTrackbar(cl_trackbar_name, window_name, &cl_trackbar_value, classes-1);
#       |         ^~~~~~~~~
# ./src/image_opencv.cpp:1430:9: warning: unused variable ‘bo_tb_res’ [-Wunused-variable]
#  1430 |     int bo_tb_res = cv::createTrackbar(bo_trackbar_name, window_name, boxonly, 1);
#       |         ^~~~~~~~~
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:253:21: warning: unused variable ‘n’ [-Wunused-variable]
#   253 |                 int n = _write(client, outputbuf, outlen);
#       |                     ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:866:27: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<detection_t>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   866 |         for (int i = 0; i < v.size(); ++i) {
#       |                         ~~^~~~~~~~~~
# ./src/http_stream.cpp:874:33: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<detection_t>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   874 |     for (int old_id = 0; old_id < old_dets.size(); ++old_id) {
#       |                          ~~~~~~~^~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:893:31: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<detection_t>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   893 |     for (int index = 0; index < new_dets_num*old_dets.size(); ++index) {
#       |                         ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:929:28: warning: comparison of integer expressions of different signedness: ‘std::deque<std::vector<detection_t> >::size_type’ {aka ‘long unsigned int’} and ‘int’ [-Wsign-compare]
#   929 |     if (old_dets_dq.size() > deque_size) old_dets_dq.pop_front();
#       |         ~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2042:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#  2042 |     const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#       |               ^~~~~
# ./src/gemm.c:2041:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#  2041 |     const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#       |               ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/utils.c -o obj/utils.o
# ./src/utils.c: In function ‘custom_hash’:
# ./src/utils.c:1093:12: warning: suggest parentheses around assignment used as truth value [-Wparentheses]
#  1093 |     while (c = *str++)
#       |            ^
# In file included from /usr/include/string.h:535,
#                  from include/darknet.h:14,
#                  from ./src/utils.h:3,
#                  from ./src/utils.c:4:
# In function ‘strncpy’,
#     inlined from ‘copy_string’ at ./src/utils.c:563:5:
# /usr/include/x86_64-linux-gnu/bits/string_fortified.h:95:10: warning: ‘__builtin_strncpy’ specified bound depends on the length of the source argument [-Wstringop-truncation]
#    95 |   return __builtin___strncpy_chk (__dest, __src, __len,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    96 |                                   __glibc_objsize (__dest));
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/utils.c: In function ‘copy_string’:
# ./src/utils.c:563:22: note: length computed here
#   563 |     strncpy(copy, s, strlen(s)+1);
#       |                      ^~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘cudnn_check_error_extended’:
# ./src/dark_cuda.c:218:20: warning: comparison between ‘cudaError_t’ {aka ‘enum cudaError’} and ‘enum <anonymous>’ [-Wenum-compare]
#   218 |         if (status != CUDNN_STATUS_SUCCESS)
#       |                    ^~
# ./src/dark_cuda.c: In function ‘cublas_check_error_extended’:
# ./src/dark_cuda.c:252:18: warning: comparison between ‘cudaError_t’ {aka ‘enum cudaError’} and ‘enum cudaError_enum’ [-Wenum-compare]
#   252 |       if (status != CUDA_SUCCESS)
#       |                  ^~
# At top level:
# ./src/dark_cuda.c:275:23: warning: ‘switchBlasHandle’ defined but not used [-Wunused-variable]
#   275 | static cublasHandle_t switchBlasHandle[16];
#       |                       ^~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:274:12: warning: ‘switchBlasInit’ defined but not used [-Wunused-variable]
#   274 | static int switchBlasInit[16] = { 0 };
#       |            ^~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1335:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#  1335 |                         size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#       |                                ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:79:5: warning: enumeration value ‘RELU6’ not handled in switch [-Wswitch]
#    79 |     switch(a){
#       |     ^~~~~~
# ./src/activations.c:79:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:310:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#   310 |     switch(a){
#       |     ^~~~~~
# ./src/activations.c:310:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:310:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:207:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#   207 |                 int out_index = id;
#       |                     ^~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/softmax_layer.c -o obj/softmax_layer.o
# ./src/softmax_layer.c: In function ‘forward_contrastive_layer’:
# ./src/softmax_layer.c:242:27: warning: variable ‘max_truth’ set but not used [-Wunused-but-set-variable]
#   242 |                     float max_truth = 0;
#       |                           ^~~~~~~~~
# ./src/softmax_layer.c:421:71: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t’ {aka ‘long unsigned int’} [-Wformat=]
#   421 |             printf(" Error: too large number of bboxes: contr_size = %d > max_contr_size  = %d \n", contr_size, max_contr_size);
#       |                                                                      ~^                             ~~~~~~~~~~
#       |                                                                       |                             |
#       |                                                                       int                           size_t {aka long unsigned int}
#       |                                                                      %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1289:24: warning: unused variable ‘x’ [-Wunused-variable]
#  1289 |                 int k, x, y;
#       |                        ^
# ./src/data.c:1076:43: warning: variable ‘r_scale’ set but not used [-Wunused-but-set-variable]
#  1076 |     float r1 = 0, r2 = 0, r3 = 0, r4 = 0, r_scale = 0;
#       |                                           ^~~~~~~
# ./src/data.c: In function ‘fill_truth_detection’:
# ./src/data.c:431:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   431 |             sprintf(buff, "echo %s \"Wrong annotation: w = %f\" >> bad_label.list", labelpath, w);
#       |                                 ^~                                                  ~~~~~~~~~
# ./src/data.c:431:27: note: assuming directive output of 8 bytes
#   431 |             sprintf(buff, "echo %s \"Wrong annotation: w = %f\" >> bad_label.list", labelpath, w);
#       |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 52 and 4461 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:437:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   437 |             sprintf(buff, "echo %s \"Wrong annotation: h = %f\" >> bad_label.list", labelpath, h);
#       |                                 ^~                                                  ~~~~~~~~~
# ./src/data.c:437:27: note: assuming directive output of 8 bytes
#   437 |             sprintf(buff, "echo %s \"Wrong annotation: h = %f\" >> bad_label.list", labelpath, h);
#       |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 52 and 4461 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:424:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   424 |             sprintf(buff, "echo %s \"Wrong annotation: x = %f, y = %f\" >> bad_label.list", labelpath, x, y);
#       |                                 ^~                                                          ~~~~~~~~~
# ./src/data.c:424:27: note: assuming directive output of 8 bytes
#   424 |             sprintf(buff, "echo %s \"Wrong annotation: x = %f, y = %f\" >> bad_label.list", labelpath, x, y);
#       |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/data.c:424:27: note: assuming directive output of 8 bytes
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 61 and 4784 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:417:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   417 |             sprintf(buff, "echo %s \"Wrong annotation: x = 0 or y = 0\" >> bad_label.list", labelpath);
#       |                                 ^~                                                          ~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 59 and 4154 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:404:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   404 |             sprintf(buff, "echo %s \"Wrong annotation: class_id = %d. But class_id should be [from 0 to %d]\" >> bad_label.list", labelpath, id, (classes-1));
#       |                                 ^~                                                                                                ~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 95 and 4210 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘train_network_waitkey’:
# ./src/network.c:435:13: warning: unused variable ‘ema_period’ [-Wunused-variable]
#   435 |         int ema_period = (net.max_batches - ema_start_point - 1000) * (1.0 - net.ema_alpha);
#       |             ^~~~~~~~~~
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:660:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#   660 |         if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#       |                                          ^~~~~~~~~~~~~~~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/connected_layer.c -o obj/connected_layer.o
# ./src/connected_layer.c: In function ‘forward_connected_layer_gpu’:
# ./src/connected_layer.c:346:11: warning: unused variable ‘one’ [-Wunused-variable]
#   346 |     float one = 1;    // alpha[0], beta[0]
#       |           ^~~
# ./src/connected_layer.c:344:13: warning: unused variable ‘c’ [-Wunused-variable]
#   344 |     float * c = l.output_gpu;
#       |             ^
# ./src/connected_layer.c:343:13: warning: unused variable ‘b’ [-Wunused-variable]
#   343 |     float * b = l.weights_gpu;
#       |             ^
# ./src/connected_layer.c:342:13: warning: unused variable ‘a’ [-Wunused-variable]
#   342 |     float * a = state.input;
#       |             ^
# ./src/connected_layer.c:341:9: warning: unused variable ‘n’ [-Wunused-variable]
#   341 |     int n = l.outputs;
#       |         ^
# ./src/connected_layer.c:340:9: warning: unused variable ‘k’ [-Wunused-variable]
#   340 |     int k = l.inputs;
#       |         ^
# ./src/connected_layer.c:339:9: warning: unused variable ‘m’ [-Wunused-variable]
#   339 |     int m = l.batch;
#       |         ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1761:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#  1761 |         if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#       |                                          ^~~~~~~~~~~~~~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/parser.c: In function ‘save_implicit_weights’:
# ./src/parser.c:1893:9: warning: unused variable ‘i’ [-Wunused-variable]
#  1893 |     int i;
#       |         ^
# ./src/parser.c: In function ‘get_classes_multipliers’:
# ./src/parser.c:435:40: warning: argument 1 range [18446744071562067968, 18446744073709551615] exceeds maximum object size 9223372036854775807 [-Walloc-size-larger-than=]
#   435 |         classes_multipliers = (float *)calloc(classes_counters, sizeof(float));
#       |                                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from ./src/parser.c:3:
# /usr/include/stdlib.h:543:14: note: in a call to allocation function ‘calloc’ declared here
#   543 | extern void *calloc (size_t __nmemb, size_t __size)
#       |              ^~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘box_iou_kind’:
# ./src/box.c:154:5: warning: enumeration value ‘MSE’ not handled in switch [-Wswitch]
#   154 |     switch(iou_kind) {
#       |     ^~~~~~
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:898:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#   898 |                     float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#       |                           ^~~~~~~~~
# ./src/box.c:897:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#   897 |                     float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#       |                           ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#   248 |     char *base = "results/comp4_det_test_";
#       |           ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:585:21: warning: statement with no effect [-Wunused-value]
#   585 |                     for (k; buf[k + n] != '\0'; k++)
#       |                     ^~~
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:706:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#   706 |         int mkd2 = make_directory(buff2, 0777);
#       |             ^~~~
# ./src/detector.c:704:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#   704 |         int mkd = make_directory(buff, 0777);
#       |             ^~~
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1323:24: warning: variable ‘cur_prob’ set but not used [-Wunused-but-set-variable]
#  1323 |                 double cur_prob = 0;
#       |                        ^~~~~~~~
# ./src/detector.c:1344:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#  1344 |         float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#       |               ^~~~~~~~~~~~
# ./src/detector.c:1343:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#  1343 |         float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#       |               ^~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘draw_object’:
# ./src/detector.c:1872:19: warning: unused variable ‘inv_loss’ [-Wunused-variable]
#  1872 |             float inv_loss = 1.0 / max_val_cmp(0.01, avg_loss);
#       |                   ^~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/layer.c -o obj/layer.o
# ./src/layer.c: In function ‘free_layer_custom’:
# ./src/layer.c:208:68: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#   208 |     if (l.delta_gpu && (l.optimized_memory < 1 || l.keep_delta_gpu && l.optimized_memory < 3)) cuda_free(l.delta_gpu), l.delta_gpu = NULL;
#       |                                                   ~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:146:9: warning: unused variable ‘count’ [-Wunused-variable]
#   146 |     int count = 0;
#       |         ^~~~~
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:855:13: warning: unused variable ‘time’ [-Wunused-variable]
#   855 |     clock_t time;
#       |             ^~~~
# ./src/classifier.c: In function ‘demo_classifier’:
# ./src/classifier.c:1283:49: warning: unused variable ‘tval_result’ [-Wunused-variable]
#  1283 |         struct timeval tval_before, tval_after, tval_result;
#       |                                                 ^~~~~~~~~~~
# ./src/classifier.c:1283:37: warning: unused variable ‘tval_after’ [-Wunused-variable]
#  1283 |         struct timeval tval_before, tval_after, tval_result;
#       |                                     ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# ./src/shortcut_layer.c: In function ‘make_shortcut_layer’:
# ./src/shortcut_layer.c:55:15: warning: unused variable ‘scale’ [-Wunused-variable]
#    55 |         float scale = sqrt(2. / l.nweights);
#       |               ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/representation_layer.c -o obj/representation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/demo.c -o obj/demo.o
# ./src/demo.c: In function ‘detect_in_thread’:
# ./src/demo.c:100:15: warning: unused variable ‘l’ [-Wunused-variable]
#   100 |         layer l = net.layers[net.n - 1];
#       |               ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/region_layer.c -o obj/region_layer.o
# ./src/region_layer.c: In function ‘resize_region_layer’:
# ./src/region_layer.c:63:9: warning: unused variable ‘old_h’ [-Wunused-variable]
#    63 |     int old_h = l->h;
#       |         ^~~~~
# ./src/region_layer.c:62:9: warning: unused variable ‘old_w’ [-Wunused-variable]
#    62 |     int old_w = l->w;
#       |         ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:67:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#    67 |     if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#       |                                      ^~~~~~~~~
#       |                                      |
#       |                                      float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/yolo_layer.c:74:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#    74 |     if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#       |                                      ^~~~~~~~
#       |                                      |
#       |                                      float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ...
#       |                                                     ~~~~~~~^~~~~
# ./src/yolo_layer.c:114:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#   114 |         if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#       |                                          ^~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/yolo_layer.c: In function ‘process_batch’:
# ./src/yolo_layer.c:425:25: warning: variable ‘best_match_t’ set but not used [-Wunused-but-set-variable]
#   425 |                     int best_match_t = 0;
#       |                         ^~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘forward_yolo_layer’:
# ./src/yolo_layer.c:705:11: warning: unused variable ‘avg_anyobj’ [-Wunused-variable]
#   705 |     float avg_anyobj = 0;
#       |           ^~~~~~~~~~
# ./src/yolo_layer.c:704:11: warning: unused variable ‘avg_obj’ [-Wunused-variable]
#   704 |     float avg_obj = 0;
#       |           ^~~~~~~
# ./src/yolo_layer.c:703:11: warning: unused variable ‘avg_cat’ [-Wunused-variable]
#   703 |     float avg_cat = 0;
#       |           ^~~~~~~
# ./src/yolo_layer.c:702:11: warning: unused variable ‘recall75’ [-Wunused-variable]
#   702 |     float recall75 = 0;
#       |           ^~~~~~~~
# ./src/yolo_layer.c:701:11: warning: unused variable ‘recall’ [-Wunused-variable]
#   701 |     float recall = 0;
#       |           ^~~~~~
# ./src/yolo_layer.c:700:11: warning: unused variable ‘tot_ciou_loss’ [-Wunused-variable]
#   700 |     float tot_ciou_loss = 0;
#       |           ^~~~~~~~~~~~~
# ./src/yolo_layer.c:699:11: warning: unused variable ‘tot_diou_loss’ [-Wunused-variable]
#   699 |     float tot_diou_loss = 0;
#       |           ^~~~~~~~~~~~~
# ./src/yolo_layer.c:696:11: warning: unused variable ‘tot_ciou’ [-Wunused-variable]
#   696 |     float tot_ciou = 0;
#       |           ^~~~~~~~
# ./src/yolo_layer.c:695:11: warning: unused variable ‘tot_diou’ [-Wunused-variable]
#   695 |     float tot_diou = 0;
#       |           ^~~~~~~~
# ./src/yolo_layer.c:694:11: warning: unused variable ‘tot_giou’ [-Wunused-variable]
#   694 |     float tot_giou = 0;
#       |           ^~~~~~~~
# ./src/yolo_layer.c:666:12: warning: unused variable ‘n’ [-Wunused-variable]
#   666 |     int b, n;
#       |            ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/gaussian_yolo_layer.c -o obj/gaussian_yolo_layer.o
# ./src/gaussian_yolo_layer.c: In function ‘make_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:70:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#    70 |     if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#       |                                      ^~~~~~~~~
#       |                                      |
#       |                                      float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/gaussian_yolo_layer.c:77:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#    77 |     if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#       |                                      ^~~~~~~~
#       |                                      |
#       |                                      float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/gaussian_yolo_layer.c: In function ‘resize_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:109:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#   109 |         if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#       |                                          ^~~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/gaussian_yolo_layer.c:118:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#   118 |         if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#       |                                          ^~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/sam_layer.c -o obj/sam_layer.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/network_kernels.cu -o obj/network_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/representation_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/gaussian_yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/conv_lstm_layer.o obj/scale_channels_layer.o obj/sam_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread `pkg-config --libs opencv4 2> /dev/null || pkg-config --libs opencv` -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -L/usr/local/cudnn/lib64 -lcudnn -lstdc++

# %%
# !./darknet
# Out:
# usage: ./darknet <function>

# %%
def update_yolo_config(cfg_file_path, num_classes):
    # Calculate the number of filters based on the formula
    num_anchors = 9
    filters = (num_classes + 5) * num_anchors

    # Read the config file
    with open(cfg_file_path, 'r') as file:
        lines = file.readlines()

    # Create an iterator for the lines
    lines_iter = iter(lines)

    with open(cfg_file_path, 'w') as file:
        for line in lines_iter:
            # Update filters for convolutional layers before each YOLO layer
            if line.startswith("[convolutional]"):
                # Get the next line to check the number of filters
                next_line = next(lines_iter, None)
                if next_line and "filters=" in next_line:
                    # Update the filters
                    line = next_line
                    line = f"filters={filters}\n"
                # Write the updated line back to the file
                file.write(line)
                # Write the updated filters line back to the file
                file.write(f"filters={filters}\n")
                continue  # Skip to the next iteration

            # Update classes in YOLO layers
            if line.startswith("[yolo]"):
                # Write the YOLO header back to the file
                file.write(line)
                # Look for the classes line and update it
                for _ in range(8):  # Skip the first few lines after [yolo]
                    next_line = next(lines_iter, None)
                    if next_line and "classes=" in next_line:
                        file.write(f"classes={num_classes}\n")
                    else:
                        file.write(next_line)
                continue

            # Write the line back to the file
            file.write(line)

# Specify the path to your configuration file and the number of classes
cfg_file_path = "/content/darknet/cfg/yolov7-tiny.cfg"
num_classes = 2

update_yolo_config(cfg_file_path, num_classes)

print(f"Updated {cfg_file_path} for {num_classes} classes with appropriate filters.")
# Out:
# Updated /content/darknet/cfg/yolov7-tiny.cfg for 2 classes with appropriate filters.

# %%
def update_yolo_config(cfg_file_path, num_classes):
    # Calculate the number of filters based on the formula
    num_anchors = 9
    filters = (num_classes + 5) * num_anchors

    # Read the config file
    with open(cfg_file_path, 'r') as file:
        lines = file.readlines()

    # Create an iterator for the lines
    lines_iter = iter(lines)

    with open(cfg_file_path, 'w') as file:
        for line in lines_iter:
            # Update filters for convolutional layers before each YOLO layer
            if line.startswith("[convolutional]"):
                # Write the convolutional header back to the file
                file.write(line)

                # Get the next line to check the number of filters
                next_line = next(lines_iter, None)
                if next_line and "filters=" in next_line:
                    # Update the filters
                    next_line = f"filters={filters}\n"

                # Write the updated filters line back to the file
                file.write(next_line)

                # Continue writing the rest of the convolutional layer settings
                for _ in range(3):  # Assuming there are three additional settings per convolutional layer
                    file.write(next(lines_iter))

                continue  # Skip to the next iteration

            # Update classes in YOLO layers
            if line.startswith("[yolo]"):
                # Write the YOLO header back to the file
                file.write(line)

                # Look for the classes line and update it
                for _ in range(8):  # Skip the first few lines after [yolo]
                    next_line = next(lines_iter, None)
                    if next_line and "classes=" in next_line:
                        file.write(f"classes={num_classes}\n")
                    else:
                        file.write(next_line)
                continue

            # Write the line back to the file
            file.write(line)

# Specify the path to your configuration file and the number of classes
cfg_file_path = "/content/darknet/cfg/yolov7-tiny.cfg"
num_classes = 2

update_yolo_config(cfg_file_path, num_classes)

print(f"Updated {cfg_file_path} for {num_classes} classes with appropriate filters.")
# Out:
# Updated /content/darknet/cfg/yolov7-tiny.cfg for 2 classes with appropriate filters.

# %%
def update_yolo_config(cfg_file_path, num_classes):
    # Calculate the number of filters based on the formula
    num_anchors = 9
    filters = (num_classes + 5) * num_anchors

    # Read the config file
    with open(cfg_file_path, 'r') as file:
        lines = file.readlines()

    # Create an iterator for the lines
    lines_iter = iter(lines)

    with open(cfg_file_path, 'w') as file:
        for line in lines_iter:
            # Update max_batches, steps, and scales
            if line.startswith("max_batches="):
                file.write("max_batches=4000\n")
                continue

            if line.startswith("steps="):
                file.write("steps=500,1000,2000,3000\n")
                continue

            if line.startswith("scales="):
                file.write("scales=0.1,0.1,0.1,0.1\n")  # Adjust this based on your needs
                continue

            # Update filters for convolutional layers before each YOLO layer
            if line.startswith("[convolutional]"):
                # Write the convolutional header back to the file
                file.write(line)

                # Get the next line to check the number of filters
                next_line = next(lines_iter, None)
                if next_line and "filters=" in next_line:
                    # Update the filters
                    next_line = f"filters={filters}\n"

                # Write the updated filters line back to the file
                file.write(next_line)

                # Continue writing the rest of the convolutional layer settings
                for _ in range(3):  # Assuming there are three additional settings per convolutional layer
                    file.write(next(lines_iter))

                continue  # Skip to the next iteration

            # Update classes in YOLO layers
            if line.startswith("[yolo]"):
                # Write the YOLO header back to the file
                file.write(line)

                # Look for the classes line and update it
                for _ in range(8):  # Skip the first few lines after [yolo]
                    next_line = next(lines_iter, None)
                    if next_line and "classes=" in next_line:
                        file.write(f"classes={num_classes}\n")
                    else:
                        file.write(next_line)
                continue

            # Write the line back to the file
            file.write(line)

# Specify the path to your configuration file and the number of classes
cfg_file_path = "/content/darknet/cfg/yolov7-tiny.cfg"
num_classes = 2

update_yolo_config(cfg_file_path, num_classes)

print(f"Updated {cfg_file_path} for {num_classes} classes with appropriate filters.")
# Out:
# Updated /content/darknet/cfg/yolov7-tiny.cfg for 2 classes with appropriate filters.

# %%
def update_yolo_config(cfg_file_path, num_classes):
    # Filter எண்ணிக்கையை கணக்கிடும் (filters calculation)
    num_anchors = 9
    filters = (num_classes + 5) * num_anchors  # filters = (num_classes + 5) * num_anchors

    # config கோப்பைப் படிக்கவும் (Read the config file)
    with open(cfg_file_path, 'r') as file:
        lines = file.readlines()

    # வரிகளுக்கான итераட்டர் உருவாக்கவும் (Create an iterator for the lines)
    lines_iter = iter(lines)

    with open(cfg_file_path, 'w') as file:
        for line in lines_iter:
            # max_batches, steps, மற்றும் scales இனைப் புதுப்பிக்கவும் (Update max_batches, steps, and scales)
            if line.startswith("max_batches="):
                file.write("max_batches=4000\n")  # Max Batches: 4000
                continue

            if line.startswith("steps="):
                file.write("steps=500,1000,2000,3000\n")  # Steps: 500,1000,2000,3000
                continue

            if line.startswith("scales="):
                file.write("scales=0.1,0.1,0.1,0.1\n")  # Scales: 0.1,0.1,0.1,0.1
                continue

            # convolutional அடுக்குகளில் filters ஐப் புதுப்பிக்கவும் (Update filters in convolutional layers)
            if line.startswith("[convolutional]"):
                file.write(line)  # convolutional header-ஐ மீண்டும் எழுதவும்

                next_line = next(lines_iter, None)
                if next_line and "filters=" in next_line:
                    # filters=13 ஐ சரிபார்க்கவும் (Check for filters=13)
                    if "filters=13" in next_line:
                        next_line = f"filters=13\n"  # filters=13 ஐ உள்ளடக்கவும்
                    else:
                        next_line = f"filters={filters}\n"  # மற்ற filters ஐ புதுப்பிக்கவும்

                file.write(next_line)  # புதுப்பிக்கப்பட்ட filters ஐ எழுதவும்

                # convolutional அடுக்குகளில் உள்ள பிற கட்டுப்பாடுகளை தொடருங்கள் (Continue writing other settings)
                for _ in range(3):  # இங்கு 3 என்று எடுத்துக்கொள்கிறோம்
                    file.write(next(lines_iter))

                continue  # அடுத்த iterationக்கு செல்லவும்

            # YOLO அடுக்குகளில் classes ஐப் புதுப்பிக்கவும் (Update classes in YOLO layers)
            if line.startswith("[yolo]"):
                file.write(line)  # YOLO header-ஐ மீண்டும் எழுதவும்

                for _ in range(8):  # YOLOக்கு பிறகு சில வரிகளை தவிர்க்கவும்
                    next_line = next(lines_iter, None)
                    if next_line and "classes=" in next_line:
                        file.write(f"classes={num_classes}\n")  # classes ஐப் புதுப்பிக்கவும்
                    else:
                        file.write(next_line)  # பிற வரிகளை எழுதவும்
                continue

            # கோப்பில் வரியை எழுதவும் (Write the line back to the file)
            file.write(line)

# உங்கள் configuration கோப்பிற்கு மற்றும் வகுப்புகளின் எண்ணிக்கைக்கு பாதையை குறிப்பிட்டு (Specify the path to your configuration file and the number of classes)
cfg_file_path = "/content/darknet/cfg/yolov7-tiny.cfg"
num_classes = 2

update_yolo_config(cfg_file_path, num_classes)

print(f"Updated {cfg_file_path} for {num_classes} classes with appropriate filters.")
# Out:
# Updated /content/darknet/cfg/yolov7-tiny.cfg for 2 classes with appropriate filters.

# %%
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov3-tiny.weights
# Out:
# --2024-10-21 07:19:24--  https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov3-tiny.weights
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-10-21 07:19:24 ERROR 404: Not Found.

# %%
# !./darknet detector train /content/darknet/cfg/coco.data  /content/darknet/cfg/yolov7-tiny.cfg  /content/darknet/yolov7-tiny.weights
# Out:
# Streaming output truncated to the last 5000 lines.
#  3501: 0.682204, 0.618539 avg loss, 0.000000 rate, 1.162179 seconds, 224064 images, 0.151202 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000081 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 4, class_loss = 0.001777, iou_loss = 0.000108, total_loss = 0.001884
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.491619), count: 48, class_loss = 0.403563, iou_loss = 0.137750, total_loss = 0.541314
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.460556), count: 150, class_loss = 1.561387, iou_loss = 0.042439, total_loss = 1.603826
#  total_bbox = 613796, rewritten_bbox = 0.034865 %
#
#  Tensor Cores are used.
# 3502/4000: loss=0.7 hours left=0.2
#  3502: 0.656109, 0.622296 avg loss, 0.000000 rate, 1.183426 seconds, 224128 images, 0.151301 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000081 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 6, class_loss = 0.000474, iou_loss = 0.000203, total_loss = 0.000677
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.434062), count: 35, class_loss = 0.178016, iou_loss = 0.075586, total_loss = 0.253602
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.467888), count: 140, class_loss = 1.504437, iou_loss = 0.038391, total_loss = 1.542828
#  total_bbox = 613977, rewritten_bbox = 0.034855 %
#
#  Tensor Cores are used.
# 3503/4000: loss=0.6 hours left=0.2
#  3503: 0.561522, 0.616219 avg loss, 0.000000 rate, 0.986626 seconds, 224192 images, 0.151425 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000079 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 3, class_loss = 0.001538, iou_loss = 0.000129, total_loss = 0.001667
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.449477), count: 37, class_loss = 0.243792, iou_loss = 0.086749, total_loss = 0.330541
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.479496), count: 155, class_loss = 2.062229, iou_loss = 0.044444, total_loss = 2.106673
#  total_bbox = 614172, rewritten_bbox = 0.034844 %
#
#  Tensor Cores are used.
# 3504/4000: loss=0.8 hours left=0.2
#  3504: 0.769726, 0.631569 avg loss, 0.000000 rate, 0.882127 seconds, 224256 images, 0.151273 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000062 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 3, class_loss = 0.015881, iou_loss = 0.000091, total_loss = 0.015972
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.447516), count: 40, class_loss = 0.246449, iou_loss = 0.085752, total_loss = 0.332201
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.474948), count: 138, class_loss = 1.712117, iou_loss = 0.039867, total_loss = 1.751985
#  total_bbox = 614353, rewritten_bbox = 0.034833 %
#
#  Tensor Cores are used.
# 3505/4000: loss=0.7 hours left=0.2
#  3505: 0.658690, 0.634281 avg loss, 0.000000 rate, 0.884101 seconds, 224320 images, 0.150976 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000087 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 6, class_loss = 0.000938, iou_loss = 0.000426, total_loss = 0.001364
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.464917), count: 51, class_loss = 0.293610, iou_loss = 0.117207, total_loss = 0.410817
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.472535), count: 135, class_loss = 1.473917, iou_loss = 0.038509, total_loss = 1.512426
#  total_bbox = 614545, rewritten_bbox = 0.034985 %
#
#  Tensor Cores are used.
# 3506/4000: loss=0.6 hours left=0.2
#  3506: 0.590025, 0.629856 avg loss, 0.000000 rate, 0.877316 seconds, 224384 images, 0.150682 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000084 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 1, class_loss = 0.000460, iou_loss = 0.000000, total_loss = 0.000460
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.411355), count: 43, class_loss = 0.419700, iou_loss = 0.077365, total_loss = 0.497065
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.457080), count: 146, class_loss = 1.567330, iou_loss = 0.040828, total_loss = 1.608159
#  total_bbox = 614734, rewritten_bbox = 0.034974 %
#
#  Tensor Cores are used.
# 3507/4000: loss=0.7 hours left=0.2
#  3507: 0.662791, 0.633149 avg loss, 0.000000 rate, 0.725719 seconds, 224448 images, 0.150379 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000088 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 2, class_loss = 0.002080, iou_loss = 0.000106, total_loss = 0.002186
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.456920), count: 29, class_loss = 0.180430, iou_loss = 0.068831, total_loss = 0.249261
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.479158), count: 126, class_loss = 1.642671, iou_loss = 0.035192, total_loss = 1.677862
#  total_bbox = 614891, rewritten_bbox = 0.034966 %
#
#  Tensor Cores are used.
# 3508/4000: loss=0.6 hours left=0.1
#  3508: 0.608931, 0.630728 avg loss, 0.000000 rate, 0.850132 seconds, 224512 images, 0.149869 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000061 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 4, class_loss = 0.000574, iou_loss = 0.000296, total_loss = 0.000870
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.420724), count: 47, class_loss = 0.342320, iou_loss = 0.081503, total_loss = 0.423823
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.475928), count: 133, class_loss = 1.597055, iou_loss = 0.036677, total_loss = 1.633732
#  total_bbox = 615075, rewritten_bbox = 0.034955 %
#
#  Tensor Cores are used.
# 3509/4000: loss=0.6 hours left=0.1
#  3509: 0.647197, 0.632375 avg loss, 0.000000 rate, 0.874209 seconds, 224576 images, 0.149533 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000105 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 10, class_loss = 0.042493, iou_loss = 0.003120, total_loss = 0.045613
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.397166), count: 49, class_loss = 0.267182, iou_loss = 0.096624, total_loss = 0.363805
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.459903), count: 141, class_loss = 1.649158, iou_loss = 0.038716, total_loss = 1.687873
#  total_bbox = 615275, rewritten_bbox = 0.034944 %
#
#  Tensor Cores are used.
# 3510/4000: loss=0.7 hours left=0.1
#  3510: 0.653502, 0.634487 avg loss, 0.000000 rate, 0.829064 seconds, 224640 images, 0.149230 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000077 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 8, class_loss = 0.015878, iou_loss = 0.000609, total_loss = 0.016487
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.432046), count: 33, class_loss = 0.186756, iou_loss = 0.081851, total_loss = 0.268607
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.468897), count: 134, class_loss = 1.404740, iou_loss = 0.037440, total_loss = 1.442180
#  total_bbox = 615450, rewritten_bbox = 0.034934 %
#
#  Tensor Cores are used.
# 3511/4000: loss=0.5 hours left=0.1
#  3511: 0.536338, 0.624672 avg loss, 0.000000 rate, 0.879155 seconds, 224704 images, 0.148866 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000070 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 2, class_loss = 0.000443, iou_loss = 0.000039, total_loss = 0.000482
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.446866), count: 33, class_loss = 0.252723, iou_loss = 0.076303, total_loss = 0.329026
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.474372), count: 131, class_loss = 1.935752, iou_loss = 0.035012, total_loss = 1.970764
#  total_bbox = 615616, rewritten_bbox = 0.034924 %
#
#  Tensor Cores are used.
# 3512/4000: loss=0.7 hours left=0.1
#  3512: 0.730181, 0.635223 avg loss, 0.000000 rate, 0.877705 seconds, 224768 images, 0.148572 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000068 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 2, class_loss = 0.000464, iou_loss = 0.000026, total_loss = 0.000491
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.390744), count: 32, class_loss = 0.182261, iou_loss = 0.045682, total_loss = 0.227943
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.464150), count: 143, class_loss = 1.407613, iou_loss = 0.039526, total_loss = 1.447139
#  total_bbox = 615793, rewritten_bbox = 0.034914 %
#
#  Tensor Cores are used.
# 3513/4000: loss=0.5 hours left=0.1
#  3513: 0.530671, 0.624768 avg loss, 0.000000 rate, 0.848622 seconds, 224832 images, 0.148276 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000089 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 10, class_loss = 0.031796, iou_loss = 0.001596, total_loss = 0.033391
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.436747), count: 53, class_loss = 0.358865, iou_loss = 0.113533, total_loss = 0.472397
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.450331), count: 124, class_loss = 1.304403, iou_loss = 0.039122, total_loss = 1.343525
#  total_bbox = 615980, rewritten_bbox = 0.034904 %
#
#  Tensor Cores are used.
# 3514/4000: loss=0.6 hours left=0.1
#  3514: 0.565571, 0.618848 avg loss, 0.000000 rate, 0.877500 seconds, 224896 images, 0.147941 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000081 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 5, class_loss = 0.000489, iou_loss = 0.000228, total_loss = 0.000717
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.423404), count: 46, class_loss = 0.309502, iou_loss = 0.087282, total_loss = 0.396784
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.441791), count: 121, class_loss = 1.370118, iou_loss = 0.032518, total_loss = 1.402636
#  total_bbox = 616152, rewritten_bbox = 0.034894 %
#
#  Tensor Cores are used.
# 3515/4000: loss=0.6 hours left=0.1
#  3515: 0.560592, 0.613023 avg loss, 0.000000 rate, 1.137007 seconds, 224960 images, 0.147647 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000100 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 2, class_loss = 0.000559, iou_loss = 0.000032, total_loss = 0.000591
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.406037), count: 26, class_loss = 0.208162, iou_loss = 0.055844, total_loss = 0.264005
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.475975), count: 144, class_loss = 1.804902, iou_loss = 0.039808, total_loss = 1.844710
#  total_bbox = 616324, rewritten_bbox = 0.034884 %
#
#  Tensor Cores are used.
# 3516/4000: loss=0.7 hours left=0.1
#  3516: 0.671759, 0.618896 avg loss, 0.000000 rate, 1.132724 seconds, 225024 images, 0.147702 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000096 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.055037), count: 5, class_loss = 0.011623, iou_loss = 0.007328, total_loss = 0.018951
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.373544), count: 29, class_loss = 0.210782, iou_loss = 0.040020, total_loss = 0.250802
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.468859), count: 150, class_loss = 1.519660, iou_loss = 0.042394, total_loss = 1.562054
#  total_bbox = 616508, rewritten_bbox = 0.034874 %
#
#  Tensor Cores are used.
# 3517/4000: loss=0.6 hours left=0.1
#  3517: 0.581236, 0.615130 avg loss, 0.000000 rate, 1.119344 seconds, 225088 images, 0.147748 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000098 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 4, class_loss = 0.014005, iou_loss = 0.000482, total_loss = 0.014487
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.470367), count: 45, class_loss = 0.263240, iou_loss = 0.120152, total_loss = 0.383391
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.491720), count: 117, class_loss = 1.836659, iou_loss = 0.034371, total_loss = 1.871030
#  total_bbox = 616674, rewritten_bbox = 0.034864 %
#
#  Tensor Cores are used.
# 3518/4000: loss=0.7 hours left=0.1
#  3518: 0.705165, 0.624134 avg loss, 0.000000 rate, 0.838857 seconds, 225152 images, 0.147772 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000073 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 1, class_loss = 0.000458, iou_loss = 0.000012, total_loss = 0.000470
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.452082), count: 26, class_loss = 0.158164, iou_loss = 0.060674, total_loss = 0.218838
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.481700), count: 135, class_loss = 1.891687, iou_loss = 0.040237, total_loss = 1.931924
#  total_bbox = 616836, rewritten_bbox = 0.034855 %
#
#  Tensor Cores are used.
# 3519/4000: loss=0.7 hours left=0.1
#  3519: 0.683975, 0.630118 avg loss, 0.000000 rate, 0.877260 seconds, 225216 images, 0.147418 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000102 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 1, class_loss = 0.000448, iou_loss = 0.000000, total_loss = 0.000448
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.466305), count: 32, class_loss = 0.237545, iou_loss = 0.068139, total_loss = 0.305684
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.479860), count: 123, class_loss = 1.492944, iou_loss = 0.039418, total_loss = 1.532362
#  total_bbox = 616991, rewritten_bbox = 0.034847 %
#
#  Tensor Cores are used.
# 3520/4000: loss=0.6 hours left=0.1
#  3520: 0.577254, 0.624831 avg loss, 0.000000 rate, 0.862576 seconds, 225280 images, 0.147116 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000072 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 3, class_loss = 0.000516, iou_loss = 0.000044, total_loss = 0.000560
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.465469), count: 32, class_loss = 0.204351, iou_loss = 0.089317, total_loss = 0.293668
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.489974), count: 126, class_loss = 1.639735, iou_loss = 0.036756, total_loss = 1.676491
#  total_bbox = 617152, rewritten_bbox = 0.034837 %
#
#  Tensor Cores are used.
# 3521/4000: loss=0.6 hours left=0.1
#  3521: 0.615400, 0.623888 avg loss, 0.000000 rate, 0.764585 seconds, 225344 images, 0.146795 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000096 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 2, class_loss = 0.000447, iou_loss = 0.000088, total_loss = 0.000535
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.439087), count: 30, class_loss = 0.156397, iou_loss = 0.066772, total_loss = 0.223169
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.472686), count: 141, class_loss = 1.574818, iou_loss = 0.039196, total_loss = 1.614014
#  total_bbox = 617325, rewritten_bbox = 0.034828 %
#
#  Tensor Cores are used.
# 3522/4000: loss=0.6 hours left=0.1
#  3522: 0.577764, 0.619276 avg loss, 0.000000 rate, 0.860961 seconds, 225408 images, 0.146345 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000070 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 3, class_loss = 0.000570, iou_loss = 0.000050, total_loss = 0.000621
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.476119), count: 49, class_loss = 0.344268, iou_loss = 0.127579, total_loss = 0.471847
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.465655), count: 143, class_loss = 1.673418, iou_loss = 0.044965, total_loss = 1.718383
#  total_bbox = 617520, rewritten_bbox = 0.034817 %
#
#  Tensor Cores are used.
# 3523/4000: loss=0.7 hours left=0.1
#  3523: 0.673288, 0.624677 avg loss, 0.000000 rate, 0.870364 seconds, 225472 images, 0.146025 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000075 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 6, class_loss = 0.016032, iou_loss = 0.002246, total_loss = 0.018278
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.436141), count: 23, class_loss = 0.159259, iou_loss = 0.057445, total_loss = 0.216704
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.495839), count: 123, class_loss = 1.563224, iou_loss = 0.032627, total_loss = 1.595851
#  total_bbox = 617672, rewritten_bbox = 0.034808 %
#
#  Tensor Cores are used.
# 3524/4000: loss=0.6 hours left=0.1
#  3524: 0.580044, 0.620214 avg loss, 0.000000 rate, 0.867392 seconds, 225536 images, 0.145718 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000069 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 1, class_loss = 0.000431, iou_loss = 0.000000, total_loss = 0.000431
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.446092), count: 43, class_loss = 0.266918, iou_loss = 0.084216, total_loss = 0.351134
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.468891), count: 128, class_loss = 1.373154, iou_loss = 0.036842, total_loss = 1.409995
#  total_bbox = 617843, rewritten_bbox = 0.034798 %
#
#  Tensor Cores are used.
# 3525/4000: loss=0.5 hours left=0.1
#  3525: 0.547117, 0.612904 avg loss, 0.000000 rate, 0.876194 seconds, 225600 images, 0.145407 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000068 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 5, class_loss = 0.000493, iou_loss = 0.000390, total_loss = 0.000883
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.402314), count: 32, class_loss = 0.201805, iou_loss = 0.053172, total_loss = 0.254976
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.457254), count: 136, class_loss = 1.369862, iou_loss = 0.035543, total_loss = 1.405405
#  total_bbox = 618016, rewritten_bbox = 0.034789 %
#
#  Tensor Cores are used.
# 3526/4000: loss=0.5 hours left=0.1
#  3526: 0.524611, 0.604075 avg loss, 0.000000 rate, 0.875989 seconds, 225664 images, 0.145110 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000062 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 3, class_loss = 0.000468, iou_loss = 0.000115, total_loss = 0.000583
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.444674), count: 30, class_loss = 0.179771, iou_loss = 0.066033, total_loss = 0.245804
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.470908), count: 128, class_loss = 1.561405, iou_loss = 0.037943, total_loss = 1.599349
#  total_bbox = 618177, rewritten_bbox = 0.034780 %
#
#  Tensor Cores are used.
# 3527/4000: loss=0.6 hours left=0.1
#  3527: 0.581091, 0.601776 avg loss, 0.000000 rate, 0.873521 seconds, 225728 images, 0.144812 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000088 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 6, class_loss = 0.006038, iou_loss = 0.000874, total_loss = 0.006912
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.369539), count: 38, class_loss = 0.219283, iou_loss = 0.055821, total_loss = 0.275103
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.474726), count: 141, class_loss = 1.471727, iou_loss = 0.041343, total_loss = 1.513070
#  total_bbox = 618362, rewritten_bbox = 0.034769 %
#
#  Tensor Cores are used.
# 3528/4000: loss=0.6 hours left=0.1
#  3528: 0.566244, 0.598223 avg loss, 0.000000 rate, 0.878131 seconds, 225792 images, 0.144512 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000080 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 2, class_loss = 0.000450, iou_loss = 0.000057, total_loss = 0.000506
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.451609), count: 40, class_loss = 0.243031, iou_loss = 0.096257, total_loss = 0.339289
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.467299), count: 120, class_loss = 1.483849, iou_loss = 0.035842, total_loss = 1.519691
#  total_bbox = 618524, rewritten_bbox = 0.034760 %
#
#  Tensor Cores are used.
# 3529/4000: loss=0.6 hours left=0.1
#  3529: 0.576319, 0.596033 avg loss, 0.000000 rate, 0.948389 seconds, 225856 images, 0.144218 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000098 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 5, class_loss = 0.000717, iou_loss = 0.000089, total_loss = 0.000807
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.502072), count: 40, class_loss = 0.193842, iou_loss = 0.121851, total_loss = 0.315693
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.485262), count: 127, class_loss = 1.747914, iou_loss = 0.043186, total_loss = 1.791100
#  total_bbox = 618696, rewritten_bbox = 0.034751 %
#
#  Tensor Cores are used.
# 3530/4000: loss=0.6 hours left=0.1
#  3530: 0.648015, 0.601231 avg loss, 0.000000 rate, 1.246710 seconds, 225920 images, 0.144017 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000085 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.035492), count: 7, class_loss = 0.012873, iou_loss = 0.016088, total_loss = 0.028960
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.400109), count: 34, class_loss = 0.220172, iou_loss = 0.062591, total_loss = 0.282763
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.469621), count: 130, class_loss = 1.364339, iou_loss = 0.037801, total_loss = 1.402141
#  total_bbox = 618867, rewritten_bbox = 0.034741 %
#
#  Tensor Cores are used.
# 3531/4000: loss=0.5 hours left=0.1
#  3531: 0.533007, 0.594408 avg loss, 0.000000 rate, 1.250549 seconds, 225984 images, 0.144204 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000075 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 3, class_loss = 0.000503, iou_loss = 0.000064, total_loss = 0.000567
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.443119), count: 24, class_loss = 0.167550, iou_loss = 0.040511, total_loss = 0.208061
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.500457), count: 131, class_loss = 1.528385, iou_loss = 0.041091, total_loss = 1.569476
#  total_bbox = 619025, rewritten_bbox = 0.034732 %
#
#  Tensor Cores are used.
# 3532/4000: loss=0.6 hours left=0.1
#  3532: 0.566015, 0.591569 avg loss, 0.000000 rate, 0.773602 seconds, 226048 images, 0.144392 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000091 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 4, class_loss = 0.000727, iou_loss = 0.000256, total_loss = 0.000984
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.442161), count: 34, class_loss = 0.216282, iou_loss = 0.077769, total_loss = 0.294052
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.484775), count: 130, class_loss = 1.410162, iou_loss = 0.034637, total_loss = 1.444799
#  total_bbox = 619193, rewritten_bbox = 0.034723 %
#
#  Tensor Cores are used.
# 3533/4000: loss=0.5 hours left=0.1
#  3533: 0.542931, 0.586705 avg loss, 0.000000 rate, 0.837804 seconds, 226112 images, 0.143954 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000074 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 6, class_loss = 0.001444, iou_loss = 0.000491, total_loss = 0.001935
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.414361), count: 27, class_loss = 0.144350, iou_loss = 0.058160, total_loss = 0.202509
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.493686), count: 130, class_loss = 1.731637, iou_loss = 0.036140, total_loss = 1.767777
#  total_bbox = 619356, rewritten_bbox = 0.034713 %
#
#  Tensor Cores are used.
# 3534/4000: loss=0.6 hours left=0.1
#  3534: 0.626355, 0.590670 avg loss, 0.000000 rate, 0.844354 seconds, 226176 images, 0.143601 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000065 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 3, class_loss = 0.000549, iou_loss = 0.000151, total_loss = 0.000700
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.456096), count: 28, class_loss = 0.195089, iou_loss = 0.064308, total_loss = 0.259397
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.482417), count: 130, class_loss = 1.556756, iou_loss = 0.038894, total_loss = 1.595651
#  total_bbox = 619517, rewritten_bbox = 0.034704 %
#
#  Tensor Cores are used.
# 3535/4000: loss=0.6 hours left=0.1
#  3535: 0.584668, 0.590070 avg loss, 0.000000 rate, 0.834791 seconds, 226240 images, 0.143258 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000077 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 3, class_loss = 0.000475, iou_loss = 0.000045, total_loss = 0.000520
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.466323), count: 32, class_loss = 0.196266, iou_loss = 0.089068, total_loss = 0.285334
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.478508), count: 111, class_loss = 1.449654, iou_loss = 0.030095, total_loss = 1.479748
#  total_bbox = 619663, rewritten_bbox = 0.034696 %
#
#  Tensor Cores are used.
# 3536/4000: loss=0.5 hours left=0.1
#  3536: 0.549333, 0.585996 avg loss, 0.000000 rate, 0.811519 seconds, 226304 images, 0.142904 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000094 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 8, class_loss = 0.016078, iou_loss = 0.000319, total_loss = 0.016397
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.473192), count: 29, class_loss = 0.185915, iou_loss = 0.085602, total_loss = 0.271517
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.494517), count: 137, class_loss = 1.563326, iou_loss = 0.039456, total_loss = 1.602783
#  total_bbox = 619837, rewritten_bbox = 0.034687 %
#
#  Tensor Cores are used.
# 3537/4000: loss=0.6 hours left=0.1
#  3537: 0.588969, 0.586294 avg loss, 0.000000 rate, 0.829586 seconds, 226368 images, 0.142521 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000107 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 2, class_loss = 0.010025, iou_loss = 0.000508, total_loss = 0.010532
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.473563), count: 28, class_loss = 0.199897, iou_loss = 0.072808, total_loss = 0.272705
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.498775), count: 144, class_loss = 1.739566, iou_loss = 0.043547, total_loss = 1.783113
#  total_bbox = 620011, rewritten_bbox = 0.034677 %
#
#  Tensor Cores are used.
# 3538/4000: loss=0.7 hours left=0.1
#  3538: 0.650357, 0.592700 avg loss, 0.000000 rate, 0.748394 seconds, 226432 images, 0.142163 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000085 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 1, class_loss = 0.000600, iou_loss = 0.000008, total_loss = 0.000608
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.469473), count: 32, class_loss = 0.205184, iou_loss = 0.073373, total_loss = 0.278557
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.458195), count: 135, class_loss = 1.537617, iou_loss = 0.035233, total_loss = 1.572850
#  total_bbox = 620179, rewritten_bbox = 0.034667 %
#
#  Tensor Cores are used.
# 3539/4000: loss=0.6 hours left=0.1
#  3539: 0.581673, 0.591597 avg loss, 0.000000 rate, 0.838833 seconds, 226496 images, 0.141702 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000067 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 3, class_loss = 0.000451, iou_loss = 0.000089, total_loss = 0.000540
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.471112), count: 35, class_loss = 0.207214, iou_loss = 0.088189, total_loss = 0.295403
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.465093), count: 141, class_loss = 1.530075, iou_loss = 0.036637, total_loss = 1.566712
#  total_bbox = 620358, rewritten_bbox = 0.034657 %
#
#  Tensor Cores are used.
# 3540/4000: loss=0.6 hours left=0.1
#  3540: 0.579784, 0.590416 avg loss, 0.000000 rate, 0.829439 seconds, 226560 images, 0.141359 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000067 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 6, class_loss = 0.016133, iou_loss = 0.000381, total_loss = 0.016514
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.445566), count: 37, class_loss = 0.204098, iou_loss = 0.091832, total_loss = 0.295931
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.469305), count: 118, class_loss = 1.551340, iou_loss = 0.030474, total_loss = 1.581814
#  total_bbox = 620519, rewritten_bbox = 0.034648 %
#
#  Tensor Cores are used.
# 3541/4000: loss=0.6 hours left=0.1
#  3541: 0.591067, 0.590481 avg loss, 0.000000 rate, 0.870428 seconds, 226624 images, 0.141005 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000083 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 4, class_loss = 0.016091, iou_loss = 0.000075, total_loss = 0.016166
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.438909), count: 39, class_loss = 0.254143, iou_loss = 0.092268, total_loss = 0.346411
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.472375), count: 140, class_loss = 1.636229, iou_loss = 0.045684, total_loss = 1.681913
#  total_bbox = 620702, rewritten_bbox = 0.034638 %
#
#  Tensor Cores are used.
# 3542/4000: loss=0.6 hours left=0.1
#  3542: 0.636032, 0.595036 avg loss, 0.000000 rate, 0.881348 seconds, 226688 images, 0.140705 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000068 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 2, class_loss = 0.000484, iou_loss = 0.000010, total_loss = 0.000494
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.417394), count: 35, class_loss = 0.205064, iou_loss = 0.064366, total_loss = 0.269430
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.482932), count: 132, class_loss = 1.472693, iou_loss = 0.040837, total_loss = 1.513530
#  total_bbox = 620871, rewritten_bbox = 0.034951 %
#
#  Tensor Cores are used.
# 3543/4000: loss=0.6 hours left=0.1
#  3543: 0.559960, 0.591528 avg loss, 0.000000 rate, 0.902906 seconds, 226752 images, 0.140419 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000085 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 5, class_loss = 0.007502, iou_loss = 0.000136, total_loss = 0.007638
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.473518), count: 31, class_loss = 0.206662, iou_loss = 0.085833, total_loss = 0.292495
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.485300), count: 128, class_loss = 1.434426, iou_loss = 0.037412, total_loss = 1.471838
#  total_bbox = 621034, rewritten_bbox = 0.034942 %
#
#  Tensor Cores are used.
# 3544/4000: loss=0.6 hours left=0.1
#  3544: 0.550062, 0.587382 avg loss, 0.000000 rate, 1.255482 seconds, 226816 images, 0.140162 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000074 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 2, class_loss = 0.015980, iou_loss = 0.001099, total_loss = 0.017078
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.399026), count: 34, class_loss = 0.319482, iou_loss = 0.042844, total_loss = 0.362326
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.466168), count: 135, class_loss = 1.497268, iou_loss = 0.046601, total_loss = 1.543869
#  total_bbox = 621205, rewritten_bbox = 0.034932 %
#
#  Tensor Cores are used.
# 3545/4000: loss=0.6 hours left=0.1
#  3545: 0.611466, 0.589790 avg loss, 0.000000 rate, 1.144057 seconds, 226880 images, 0.140350 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000090 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 1, class_loss = 0.000445, iou_loss = 0.000000, total_loss = 0.000445
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.404306), count: 21, class_loss = 0.178259, iou_loss = 0.026217, total_loss = 0.204475
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.489310), count: 124, class_loss = 1.500608, iou_loss = 0.033767, total_loss = 1.534375
#  total_bbox = 621350, rewritten_bbox = 0.034924 %
#
#  Tensor Cores are used.
# 3546/4000: loss=0.6 hours left=0.1
#  3546: 0.560059, 0.586817 avg loss, 0.000000 rate, 1.073115 seconds, 226944 images, 0.140393 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000072 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 5, class_loss = 0.000467, iou_loss = 0.000263, total_loss = 0.000730
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.444495), count: 23, class_loss = 0.140898, iou_loss = 0.055322, total_loss = 0.196220
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.473744), count: 142, class_loss = 1.509945, iou_loss = 0.039760, total_loss = 1.549704
#  total_bbox = 621520, rewritten_bbox = 0.034914 %
#
#  Tensor Cores are used.
# 3547/4000: loss=0.6 hours left=0.1
#  3547: 0.550979, 0.583233 avg loss, 0.000000 rate, 0.877251 seconds, 227008 images, 0.140342 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000076 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 6, class_loss = 0.000942, iou_loss = 0.000300, total_loss = 0.001242
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.483690), count: 31, class_loss = 0.167988, iou_loss = 0.096590, total_loss = 0.264579
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.486506), count: 137, class_loss = 1.869428, iou_loss = 0.042033, total_loss = 1.911461
#  total_bbox = 621694, rewritten_bbox = 0.034905 %
#
#  Tensor Cores are used.
# 3548/4000: loss=0.7 hours left=0.1
#  3548: 0.679981, 0.592908 avg loss, 0.000000 rate, 0.854590 seconds, 227072 images, 0.140043 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000065 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 7, class_loss = 0.019041, iou_loss = 0.000701, total_loss = 0.019742
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.494773), count: 39, class_loss = 0.250808, iou_loss = 0.115061, total_loss = 0.365870
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.467278), count: 123, class_loss = 1.393994, iou_loss = 0.032287, total_loss = 1.426281
#  total_bbox = 621863, rewritten_bbox = 0.034895 %
#
#  Tensor Cores are used.
# 3549/4000: loss=0.6 hours left=0.1
#  3549: 0.555145, 0.589132 avg loss, 0.000000 rate, 0.887596 seconds, 227136 images, 0.139716 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000095 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 10, class_loss = 0.028758, iou_loss = 0.002208, total_loss = 0.030966
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.452368), count: 43, class_loss = 0.304959, iou_loss = 0.103039, total_loss = 0.407998
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.487168), count: 142, class_loss = 1.688402, iou_loss = 0.043505, total_loss = 1.731907
#  total_bbox = 622058, rewritten_bbox = 0.034884 %
#
#  Tensor Cores are used.
# 3550/4000: loss=0.7 hours left=0.1
#  3550: 0.674576, 0.597676 avg loss, 0.000000 rate, 0.889748 seconds, 227200 images, 0.139431 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000088 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 2, class_loss = 0.000509, iou_loss = 0.000124, total_loss = 0.000633
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.391735), count: 35, class_loss = 0.274236, iou_loss = 0.050832, total_loss = 0.325068
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.450689), count: 134, class_loss = 1.400318, iou_loss = 0.031815, total_loss = 1.432133
#  total_bbox = 622229, rewritten_bbox = 0.034875 %
#
#  Tensor Cores are used.
# 3551/4000: loss=0.6 hours left=0.1
#  3551: 0.558916, 0.593800 avg loss, 0.000000 rate, 0.794746 seconds, 227264 images, 0.139149 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000079 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 8, class_loss = 0.017313, iou_loss = 0.001258, total_loss = 0.018571
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.444917), count: 49, class_loss = 0.391022, iou_loss = 0.107607, total_loss = 0.498629
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.442111), count: 136, class_loss = 1.355157, iou_loss = 0.041538, total_loss = 1.396695
#  total_bbox = 622421, rewritten_bbox = 0.034864 %
#
#  Tensor Cores are used.
# 3552/4000: loss=0.6 hours left=0.1
#  3552: 0.588381, 0.593258 avg loss, 0.000000 rate, 0.840808 seconds, 227328 images, 0.138748 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000094 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 1, class_loss = 0.000425, iou_loss = 0.000005, total_loss = 0.000430
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.458010), count: 41, class_loss = 0.273165, iou_loss = 0.092074, total_loss = 0.365239
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.467223), count: 126, class_loss = 1.514274, iou_loss = 0.037870, total_loss = 1.552144
#  total_bbox = 622589, rewritten_bbox = 0.034854 %
#
#  Tensor Cores are used.
# 3553/4000: loss=0.6 hours left=0.1
#  3553: 0.596495, 0.593582 avg loss, 0.000000 rate, 0.843840 seconds, 227392 images, 0.138407 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000079 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 6, class_loss = 0.017173, iou_loss = 0.003612, total_loss = 0.020786
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.431135), count: 46, class_loss = 0.308631, iou_loss = 0.102003, total_loss = 0.410634
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.482735), count: 121, class_loss = 1.609877, iou_loss = 0.038741, total_loss = 1.648618
#  total_bbox = 622762, rewritten_bbox = 0.034845 %
#
#  Tensor Cores are used.
# 3554/4000: loss=0.6 hours left=0.1
#  3554: 0.645770, 0.598801 avg loss, 0.000000 rate, 0.789446 seconds, 227456 images, 0.138071 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000095 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 3, class_loss = 0.000491, iou_loss = 0.000158, total_loss = 0.000648
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.421989), count: 35, class_loss = 0.256249, iou_loss = 0.054078, total_loss = 0.310327
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.493109), count: 118, class_loss = 1.723044, iou_loss = 0.038089, total_loss = 1.761133
#  total_bbox = 622918, rewritten_bbox = 0.034836 %
#
#  Tensor Cores are used.
# 3555/4000: loss=0.7 hours left=0.1
#  3555: 0.660471, 0.604968 avg loss, 0.000000 rate, 0.718561 seconds, 227520 images, 0.137669 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000081 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 8, class_loss = 0.026820, iou_loss = 0.000622, total_loss = 0.027442
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.487039), count: 46, class_loss = 0.274296, iou_loss = 0.136981, total_loss = 0.411277
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.492860), count: 109, class_loss = 1.360727, iou_loss = 0.032387, total_loss = 1.393114
#  total_bbox = 623081, rewritten_bbox = 0.034827 %
#
#  Tensor Cores are used.
# 3556/4000: loss=0.6 hours left=0.1
#  3556: 0.554474, 0.599918 avg loss, 0.000000 rate, 0.836091 seconds, 227584 images, 0.137180 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000078 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 3, class_loss = 0.016078, iou_loss = 0.000107, total_loss = 0.016185
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.435995), count: 38, class_loss = 0.231749, iou_loss = 0.081333, total_loss = 0.313082
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.469220), count: 150, class_loss = 1.643022, iou_loss = 0.041788, total_loss = 1.684810
#  total_bbox = 623272, rewritten_bbox = 0.034816 %
#
#  Tensor Cores are used.
# 3557/4000: loss=0.6 hours left=0.1
#  3557: 0.630829, 0.603009 avg loss, 0.000000 rate, 0.889458 seconds, 227648 images, 0.136840 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000063 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 7, class_loss = 0.000611, iou_loss = 0.000384, total_loss = 0.000996
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.434005), count: 50, class_loss = 0.286569, iou_loss = 0.096980, total_loss = 0.383549
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.482033), count: 146, class_loss = 1.541345, iou_loss = 0.047606, total_loss = 1.588951
#  total_bbox = 623475, rewritten_bbox = 0.034805 %
#
#  Tensor Cores are used.
# 3558/4000: loss=0.6 hours left=0.1
#  3558: 0.610051, 0.603714 avg loss, 0.000000 rate, 0.990122 seconds, 227712 images, 0.136566 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000095 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 2, class_loss = 0.016014, iou_loss = 0.000584, total_loss = 0.016598
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.405378), count: 21, class_loss = 0.144402, iou_loss = 0.035846, total_loss = 0.180248
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.492187), count: 132, class_loss = 1.505718, iou_loss = 0.034965, total_loss = 1.540683
#  total_bbox = 623630, rewritten_bbox = 0.034796 %
#
#  Tensor Cores are used.
# 3559/4000: loss=0.6 hours left=0.1
#  3559: 0.555925, 0.598935 avg loss, 0.000000 rate, 1.237432 seconds, 227776 images, 0.136416 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000086 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 1, class_loss = 0.000472, iou_loss = 0.000000, total_loss = 0.000472
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.403311), count: 21, class_loss = 0.149308, iou_loss = 0.034192, total_loss = 0.183501
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.482277), count: 143, class_loss = 1.807440, iou_loss = 0.039754, total_loss = 1.847194
#  total_bbox = 623794, rewritten_bbox = 0.034787 %
#
#  Tensor Cores are used.
# 3560/4000: loss=0.7 hours left=0.1
#  3560: 0.652697, 0.604311 avg loss, 0.000000 rate, 1.194180 seconds, 227840 images, 0.136568 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000084 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 6, class_loss = 0.031848, iou_loss = 0.005349, total_loss = 0.037196
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.405332), count: 42, class_loss = 0.312268, iou_loss = 0.076697, total_loss = 0.388964
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.457966), count: 136, class_loss = 1.459945, iou_loss = 0.039435, total_loss = 1.499379
#  total_bbox = 623978, rewritten_bbox = 0.034777 %
#
#  Tensor Cores are used.
# 3561/4000: loss=0.6 hours left=0.1
#  3561: 0.601910, 0.604071 avg loss, 0.000000 rate, 0.884016 seconds, 227904 images, 0.136662 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000087 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 9, class_loss = 0.017725, iou_loss = 0.000678, total_loss = 0.018403
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.447513), count: 39, class_loss = 0.180418, iou_loss = 0.095053, total_loss = 0.275471
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.483700), count: 120, class_loss = 1.438949, iou_loss = 0.035124, total_loss = 1.474073
#  total_bbox = 624146, rewritten_bbox = 0.034768 %
#
#  Tensor Cores are used.
# 3562/4000: loss=0.5 hours left=0.1
#  3562: 0.546236, 0.598287 avg loss, 0.000000 rate, 0.777699 seconds, 227968 images, 0.136373 hours left
# ...
# Loaded: 0.000071 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 2, class_loss = 0.000465, iou_loss = 0.000129, total_loss = 0.000594
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.509210), count: 40, class_loss = 0.281620, iou_loss = 0.125022, total_loss = 0.406642
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.466217), count: 117, class_loss = 1.335446, iou_loss = 0.036644, total_loss = 1.372091
#  total_bbox = 697592, rewritten_bbox = 0.034547 %
#
#  Tensor Cores are used.
# 3981/4000: loss=0.5 hours left=0.0
#  3981: 0.539704, 0.608872 avg loss, 0.000000 rate, 0.857890 seconds, 254784 images, 0.030072 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000082 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.022640), count: 10, class_loss = 0.012718, iou_loss = 0.023407, total_loss = 0.036125
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.442865), count: 37, class_loss = 0.178982, iou_loss = 0.088544, total_loss = 0.267526
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.454219), count: 106, class_loss = 1.294981, iou_loss = 0.029133, total_loss = 1.324114
#  total_bbox = 697745, rewritten_bbox = 0.034540 %
#
#  Tensor Cores are used.
# 3982/4000: loss=0.5 hours left=0.0
#  3982: 0.496102, 0.597595 avg loss, 0.000000 rate, 0.865263 seconds, 254848 images, 0.029817 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000090 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 3, class_loss = 0.016019, iou_loss = 0.000407, total_loss = 0.016426
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.507866), count: 37, class_loss = 0.240192, iou_loss = 0.117471, total_loss = 0.357663
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.466321), count: 129, class_loss = 1.616464, iou_loss = 0.040208, total_loss = 1.656672
#  total_bbox = 697914, rewritten_bbox = 0.034531 %
#
#  Tensor Cores are used.
# 3983/4000: loss=0.6 hours left=0.0
#  3983: 0.624752, 0.600311 avg loss, 0.000000 rate, 0.855407 seconds, 254912 images, 0.029562 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000090 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 8, class_loss = 0.031474, iou_loss = 0.001539, total_loss = 0.033013
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.451860), count: 38, class_loss = 0.233358, iou_loss = 0.096342, total_loss = 0.329700
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.465367), count: 120, class_loss = 1.263248, iou_loss = 0.036198, total_loss = 1.299446
#  total_bbox = 698080, rewritten_bbox = 0.034523 %
#
#  Tensor Cores are used.
# 3984/4000: loss=0.5 hours left=0.0
#  3984: 0.509902, 0.591270 avg loss, 0.000000 rate, 0.866522 seconds, 254976 images, 0.029307 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000086 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 7, class_loss = 0.001048, iou_loss = 0.000326, total_loss = 0.001374
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.420949), count: 45, class_loss = 0.346713, iou_loss = 0.087306, total_loss = 0.434020
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.464364), count: 127, class_loss = 1.588460, iou_loss = 0.039836, total_loss = 1.628296
#  total_bbox = 698259, rewritten_bbox = 0.034514 %
#
#  Tensor Cores are used.
# 3985/4000: loss=0.6 hours left=0.0
#  3985: 0.645958, 0.596739 avg loss, 0.000000 rate, 0.751598 seconds, 255040 images, 0.029052 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000120 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 1, class_loss = 0.000451, iou_loss = 0.000000, total_loss = 0.000451
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.403757), count: 21, class_loss = 0.143038, iou_loss = 0.040260, total_loss = 0.183298
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.470639), count: 136, class_loss = 1.599681, iou_loss = 0.035039, total_loss = 1.634720
#  total_bbox = 698416, rewritten_bbox = 0.034507 %
#
#  Tensor Cores are used.
# 3986/4000: loss=0.6 hours left=0.0
#  3986: 0.581350, 0.595200 avg loss, 0.000000 rate, 0.872297 seconds, 255104 images, 0.028793 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000079 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.078677), count: 3, class_loss = 0.005992, iou_loss = 0.006978, total_loss = 0.012970
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.440803), count: 52, class_loss = 0.314364, iou_loss = 0.103789, total_loss = 0.418153
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.476553), count: 126, class_loss = 1.504515, iou_loss = 0.040645, total_loss = 1.545160
#  total_bbox = 698597, rewritten_bbox = 0.034498 %
#
#  Tensor Cores are used.
# 3987/4000: loss=0.6 hours left=0.0
#  3987: 0.608812, 0.596561 avg loss, 0.000000 rate, 0.828483 seconds, 255168 images, 0.028539 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000068 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 2, class_loss = 0.000436, iou_loss = 0.000044, total_loss = 0.000480
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.467313), count: 37, class_loss = 0.266449, iou_loss = 0.103748, total_loss = 0.370197
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.497427), count: 135, class_loss = 1.772648, iou_loss = 0.040120, total_loss = 1.812768
#  total_bbox = 698771, rewritten_bbox = 0.034489 %
#
#  Tensor Cores are used.
# 3988/4000: loss=0.7 hours left=0.0
#  3988: 0.680374, 0.604942 avg loss, 0.000000 rate, 0.880095 seconds, 255232 images, 0.028284 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000090 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 1, class_loss = 0.000590, iou_loss = 0.000004, total_loss = 0.000594
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.426444), count: 52, class_loss = 0.333935, iou_loss = 0.091420, total_loss = 0.425356
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.462562), count: 131, class_loss = 1.202748, iou_loss = 0.046785, total_loss = 1.249533
#  total_bbox = 698955, rewritten_bbox = 0.034480 %
#
#  Tensor Cores are used.
# 3989/4000: loss=0.5 hours left=0.0
#  3989: 0.512974, 0.595745 avg loss, 0.000000 rate, 0.963522 seconds, 255296 images, 0.028030 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000095 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 1, class_loss = 0.000475, iou_loss = 0.000000, total_loss = 0.000475
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.468540), count: 27, class_loss = 0.216847, iou_loss = 0.051478, total_loss = 0.268325
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.465025), count: 144, class_loss = 1.514829, iou_loss = 0.039994, total_loss = 1.554823
#  total_bbox = 699126, rewritten_bbox = 0.034472 %
#
#  Tensor Cores are used.
# 3990/4000: loss=0.6 hours left=0.0
#  3990: 0.577661, 0.593937 avg loss, 0.000000 rate, 1.241826 seconds, 255360 images, 0.027779 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000079 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 2, class_loss = 0.000855, iou_loss = 0.000107, total_loss = 0.000961
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.420119), count: 35, class_loss = 0.250467, iou_loss = 0.057994, total_loss = 0.308461
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.453129), count: 171, class_loss = 1.795724, iou_loss = 0.047446, total_loss = 1.843170
#  total_bbox = 699334, rewritten_bbox = 0.034461 %
#
#  Tensor Cores are used.
# 3991/4000: loss=0.7 hours left=0.0
#  3991: 0.682903, 0.602834 avg loss, 0.000000 rate, 1.172139 seconds, 255424 images, 0.027536 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000098 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 1, class_loss = 0.000458, iou_loss = 0.000000, total_loss = 0.000458
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.443956), count: 29, class_loss = 0.230664, iou_loss = 0.061027, total_loss = 0.291691
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.461457), count: 151, class_loss = 1.546810, iou_loss = 0.040385, total_loss = 1.587195
#  total_bbox = 699514, rewritten_bbox = 0.034452 %
#
#  Tensor Cores are used.
# 3992/4000: loss=0.6 hours left=0.0
#  3992: 0.592929, 0.601843 avg loss, 0.000000 rate, 0.967174 seconds, 255488 images, 0.027290 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000108 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 5, class_loss = 0.001653, iou_loss = 0.000209, total_loss = 0.001862
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.446125), count: 46, class_loss = 0.342241, iou_loss = 0.111337, total_loss = 0.453579
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.474001), count: 132, class_loss = 1.657665, iou_loss = 0.036804, total_loss = 1.694469
#  total_bbox = 699697, rewritten_bbox = 0.034443 %
#
#  Tensor Cores are used.
# 3993/4000: loss=0.7 hours left=0.0
#  3993: 0.667728, 0.608432 avg loss, 0.000000 rate, 0.888255 seconds, 255552 images, 0.027039 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000104 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 2, class_loss = 0.000458, iou_loss = 0.000098, total_loss = 0.000556
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.480110), count: 27, class_loss = 0.178429, iou_loss = 0.073413, total_loss = 0.251842
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.470772), count: 135, class_loss = 1.588005, iou_loss = 0.037143, total_loss = 1.625148
#  total_bbox = 699861, rewritten_bbox = 0.034435 %
#
#  Tensor Cores are used.
# 3994/4000: loss=0.6 hours left=0.0
#  3994: 0.589497, 0.606538 avg loss, 0.000000 rate, 0.874805 seconds, 255616 images, 0.026785 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000083 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 5, class_loss = 0.015766, iou_loss = 0.000084, total_loss = 0.015849
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.471801), count: 52, class_loss = 0.315446, iou_loss = 0.125694, total_loss = 0.441139
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.446798), count: 135, class_loss = 1.473780, iou_loss = 0.040675, total_loss = 1.514456
#  total_bbox = 700053, rewritten_bbox = 0.034426 %
#
#  Tensor Cores are used.
# 3995/4000: loss=0.6 hours left=0.0
#  3995: 0.602206, 0.606105 avg loss, 0.000000 rate, 0.875484 seconds, 255680 images, 0.026532 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000082 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 6, class_loss = 0.004958, iou_loss = 0.000141, total_loss = 0.005099
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.445935), count: 55, class_loss = 0.361564, iou_loss = 0.118761, total_loss = 0.480325
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.463268), count: 147, class_loss = 1.688283, iou_loss = 0.041360, total_loss = 1.729644
#  total_bbox = 700261, rewritten_bbox = 0.034416 %
#
#  Tensor Cores are used.
# 3996/4000: loss=0.7 hours left=0.0
#  3996: 0.685480, 0.614043 avg loss, 0.000000 rate, 0.881437 seconds, 255744 images, 0.026279 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000072 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 6, class_loss = 0.029052, iou_loss = 0.000931, total_loss = 0.029982
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.466803), count: 35, class_loss = 0.211304, iou_loss = 0.101166, total_loss = 0.312470
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.476752), count: 117, class_loss = 1.377407, iou_loss = 0.033809, total_loss = 1.411216
#  total_bbox = 700419, rewritten_bbox = 0.034408 %
#
#  Tensor Cores are used.
# 3997/4000: loss=0.5 hours left=0.0
#  3997: 0.539790, 0.606617 avg loss, 0.000000 rate, 0.878829 seconds, 255808 images, 0.026026 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000114 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 5, class_loss = 0.016837, iou_loss = 0.000442, total_loss = 0.017280
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.474750), count: 38, class_loss = 0.262395, iou_loss = 0.099640, total_loss = 0.362035
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.471416), count: 134, class_loss = 1.684496, iou_loss = 0.037384, total_loss = 1.721879
#  total_bbox = 700596, rewritten_bbox = 0.034399 %
#
#  Tensor Cores are used.
# 3998/4000: loss=0.7 hours left=0.0
#  3998: 0.655111, 0.611467 avg loss, 0.000000 rate, 0.829647 seconds, 255872 images, 0.025773 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000100 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 2, class_loss = 0.000440, iou_loss = 0.000020, total_loss = 0.000459
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.428759), count: 18, class_loss = 0.126873, iou_loss = 0.042218, total_loss = 0.169091
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.496536), count: 115, class_loss = 1.477304, iou_loss = 0.030099, total_loss = 1.507402
#  total_bbox = 700731, rewritten_bbox = 0.034393 %
#
#  Tensor Cores are used.
# 3999/4000: loss=0.5 hours left=0.0
#  3999: 0.535412, 0.603861 avg loss, 0.000000 rate, 0.869669 seconds, 255936 images, 0.025520 hours left
# OpenCV exception: draw_train_loss()
# Loaded: 0.000077 seconds
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 90 Avg (IOU: 0.000000), count: 15, class_loss = 0.064045, iou_loss = 0.001252, total_loss = 0.065296
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 94 Avg (IOU: 0.419109), count: 50, class_loss = 0.381133, iou_loss = 0.130078, total_loss = 0.511211
# v3 (iou loss, Normalizer: (iou: 0.05, obj: 1.00, cls: 0.50) Region 98 Avg (IOU: 0.511547), count: 115, class_loss = 1.685034, iou_loss = 0.034832, total_loss = 1.719866
#  total_bbox = 700911, rewritten_bbox = 0.034384 %
#
#  Tensor Cores are used.
# 4000/4000: loss=0.7 hours left=0.0
#  4000: 0.710609, 0.614536 avg loss, 0.000000 rate, 0.866278 seconds, 256000 images, 0.025267 hours left
# OpenCV exception: draw_train_loss()
# Saving weights to /content/darknet/backup/yolov7-tiny_4000.weights
# Saving weights to /content/darknet/backup/yolov7-tiny_last.weights
# Saving weights to /content/darknet/backup/yolov7-tiny_final.weights
# If you want to train from the beginning, then use flag in the end of training command: -clear

# %%
# !./darknet detector map /content/darknet/cfg/coco.data /content/darknet/cfg/yolov7-tiny.cfg /content/darknet/backup/yolov7-tiny_final.weights
# Out:
#  CUDA-version: 12020 (12020), cuDNN: 8.9.6, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 4.5.4
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     32       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  32 0.044 BF
#    3 route  1 		                           ->  104 x 104 x  64
#    4 conv     32       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  32 0.044 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    7 route  2 4 5 6 	                   ->  104 x 104 x 128
#    8 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    9 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#   10 conv     64       1 x 1/ 1     52 x  52 x  64 ->   52 x  52 x  64 0.022 BF
#   11 route  9 		                           ->   52 x  52 x  64
#   12 conv     64       1 x 1/ 1     52 x  52 x  64 ->   52 x  52 x  64 0.022 BF
#   13 conv     64       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x  64 0.199 BF
#   14 conv     64       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x  64 0.199 BF
#   15 route  10 12 13 14 	                   ->   52 x  52 x 256
#   16 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   17 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
#   18 conv    128       1 x 1/ 1     26 x  26 x 128 ->   26 x  26 x 128 0.022 BF
#   19 route  17 		                           ->   26 x  26 x 128
#   20 conv    128       1 x 1/ 1     26 x  26 x 128 ->   26 x  26 x 128 0.022 BF
#   21 conv    128       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 128 0.199 BF
#   22 conv    128       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 128 0.199 BF
#   23 route  18 20 21 22 	                   ->   26 x  26 x 512
#   24 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   25 max                2x 2/ 2     26 x  26 x 256 ->   13 x  13 x 256 0.000 BF
#   26 conv    256       1 x 1/ 1     13 x  13 x 256 ->   13 x  13 x 256 0.022 BF
#   27 route  25 		                           ->   13 x  13 x 256
#   28 conv    256       1 x 1/ 1     13 x  13 x 256 ->   13 x  13 x 256 0.022 BF
#   29 conv    256       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 256 0.199 BF
#   30 conv    256       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 256 0.199 BF
#   31 route  26 28 29 30 	                   ->   13 x  13 x1024
#   32 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   33 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   34 route  32 		                           ->   13 x  13 x 512
#   35 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   36 max                5x 5/ 1     13 x  13 x 256 ->   13 x  13 x 256 0.001 BF
#   37 route  35 		                           ->   13 x  13 x 256
#   38 max                9x 9/ 1     13 x  13 x 256 ->   13 x  13 x 256 0.004 BF
#   39 route  35 		                           ->   13 x  13 x 256
#   40 max               13x13/ 1     13 x  13 x 256 ->   13 x  13 x 256 0.007 BF
#   41 route  40 38 36 35 	                   ->   13 x  13 x1024
#   42 conv    256       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 256 0.089 BF
#   43 route  33 42 	                           ->   13 x  13 x 512
#   44 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   45 conv    128       1 x 1/ 1     13 x  13 x 256 ->   13 x  13 x 128 0.011 BF
#   46 upsample                 2x    13 x  13 x 128 ->   26 x  26 x 128
#   47 route  24 		                           ->   26 x  26 x 256
#   48 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#   49 route  48 46 	                           ->   26 x  26 x 256
#   50 conv     64       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x  64 0.022 BF
#   51 route  49 		                           ->   26 x  26 x 256
#   52 conv     64       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x  64 0.022 BF
#   53 conv     64       3 x 3/ 1     26 x  26 x  64 ->   26 x  26 x  64 0.050 BF
#   54 conv     64       3 x 3/ 1     26 x  26 x  64 ->   26 x  26 x  64 0.050 BF
#   55 route  50 52 53 54 	                   ->   26 x  26 x 256
#   56 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#   57 conv     64       1 x 1/ 1     26 x  26 x 128 ->   26 x  26 x  64 0.011 BF
#   58 upsample                 2x    26 x  26 x  64 ->   52 x  52 x  64
#   59 route  16 		                           ->   52 x  52 x 128
#   60 conv     64       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x  64 0.044 BF
#   61 route  60 58 	                           ->   52 x  52 x 128
#   62 conv     32       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x  32 0.022 BF
#   63 route  61 		                           ->   52 x  52 x 128
#   64 conv     32       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x  32 0.022 BF
#   65 conv     32       3 x 3/ 1     52 x  52 x  32 ->   52 x  52 x  32 0.050 BF
#   66 conv     32       3 x 3/ 1     52 x  52 x  32 ->   52 x  52 x  32 0.050 BF
#   67 route  62 64 65 66 	                   ->   52 x  52 x 128
#   68 conv     64       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x  64 0.044 BF
#   69 conv    128       3 x 3/ 2     52 x  52 x  64 ->   26 x  26 x 128 0.100 BF
#   70 route  69 56 	                           ->   26 x  26 x 256
#   71 conv     64       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x  64 0.022 BF
#   72 route  70 		                           ->   26 x  26 x 256
#   73 conv     64       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x  64 0.022 BF
#   74 conv     64       3 x 3/ 1     26 x  26 x  64 ->   26 x  26 x  64 0.050 BF
#   75 conv     64       3 x 3/ 1     26 x  26 x  64 ->   26 x  26 x  64 0.050 BF
#   76 route  71 73 74 75 	                   ->   26 x  26 x 256
#   77 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#   78 conv    256       3 x 3/ 2     26 x  26 x 128 ->   13 x  13 x 256 0.100 BF
#   79 route  78 44 	                           ->   13 x  13 x 512
#   80 conv    128       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 128 0.022 BF
#   81 route  79 		                           ->   13 x  13 x 512
#   82 conv    128       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 128 0.022 BF
#   83 conv    128       3 x 3/ 1     13 x  13 x 128 ->   13 x  13 x 128 0.050 BF
#   84 conv    128       3 x 3/ 1     13 x  13 x 128 ->   13 x  13 x 128 0.050 BF
#   85 route  80 82 83 84 	                   ->   13 x  13 x 512
#   86 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   87 route  68 		                           ->   52 x  52 x  64
#   88 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#   89 conv     21       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x  21 0.015 BF
#   90 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.05, obj_norm: 1.00, cls_norm: 0.50, delta_norm: 1.00, scale_x_y: 2.00
# nms_kind: diounms (2), beta = 0.600000
#   91 route  77 		                           ->   26 x  26 x 128
#   92 conv    256       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 256 0.399 BF
#   93 conv     21       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x  21 0.007 BF
#   94 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.05, obj_norm: 1.00, cls_norm: 0.50, delta_norm: 1.00, scale_x_y: 2.00
# nms_kind: diounms (2), beta = 0.600000
#   95 route  86 		                           ->   13 x  13 x 256
#   96 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   97 conv     21       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x  21 0.004 BF
#   98 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.05, obj_norm: 1.00, cls_norm: 0.50, delta_norm: 1.00, scale_x_y: 2.00
# nms_kind: diounms (2), beta = 0.600000
# Total BFLOPS 5.518
# avg_outputs = 165602
#  Allocate additional workspace_size = 13.11 MB
# Loading weights from /content/darknet/backup/yolov7-tiny_final.weights...
#  seen 64, trained: 256 K-images (4 Kilo-batches_64)
# Done! Loaded 99 layers from weights-file
#
#  calculation mAP (mean average precision)...
#  Detection layer: 90 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 98 - type = 28
# 92
#  detections_count = 2401, unique_truth_count = 92
# class_id = 0, name = celurit, ap = 7.99%   	 (TP = 0, FP = 0)
# class_id = 1, name = pedang, ap = 9.57%   	 (TP = 0, FP = 0)
#
#  for conf_thresh = 0.25, precision = -nan, recall = 0.00, F1-score = -nan
#  for conf_thresh = 0.25, TP = 0, FP = 0, FN = 92, average IoU = 0.00 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.087778, or 8.78 %
# Total Detection Time: 2 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mv  /content/darknet/bacckup /content/drive/MyDrive/atomic-model-in-indumathi

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:253:21: warning: unused variable ‘n’ [-Wunused-variable]
#   253 |                 int n = _write(client, outputbuf, outlen);
#       |                     ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:866:27: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<detection_t>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   866 |         for (int i = 0; i < v.size(); ++i) {
#       |                         ~~^~~~~~~~~~
# ./src/http_stream.cpp:874:33: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<detection_t>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   874 |     for (int old_id = 0; old_id < old_dets.size(); ++old_id) {
#       |                          ~~~~~~~^~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:893:31: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<detection_t>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   893 |     for (int index = 0; index < new_dets_num*old_dets.size(); ++index) {
#       |                         ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:929:28: warning: comparison of integer expressions of different signedness: ‘std::deque<std::vector<detection_t> >::size_type’ {aka ‘long unsigned int’} and ‘int’ [-Wsign-compare]
#   929 |     if (old_dets_dq.size() > deque_size) old_dets_dq.pop_front();
#       |         ~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2042:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#  2042 |     const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#       |               ^~~~~
# ./src/gemm.c:2041:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#  2041 |     const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#       |               ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/utils.c -o obj/utils.o
# ./src/utils.c: In function ‘custom_hash’:
# ./src/utils.c:1093:12: warning: suggest parentheses around assignment used as truth value [-Wparentheses]
#  1093 |     while (c = *str++)
#       |            ^
# In file included from /usr/include/string.h:535,
#                  from include/darknet.h:14,
#                  from ./src/utils.h:3,
#                  from ./src/utils.c:4:
# In function ‘strncpy’,
#     inlined from ‘copy_string’ at ./src/utils.c:563:5:
# /usr/include/x86_64-linux-gnu/bits/string_fortified.h:95:10: warning: ‘__builtin_strncpy’ specified bound depends on the length of the source argument [-Wstringop-truncation]
#    95 |   return __builtin___strncpy_chk (__dest, __src, __len,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    96 |                                   __glibc_objsize (__dest));
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/utils.c: In function ‘copy_string’:
# ./src/utils.c:563:22: note: length computed here
#   563 |     strncpy(copy, s, strlen(s)+1);
#       |                      ^~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘cudnn_check_error_extended’:
# ./src/dark_cuda.c:218:20: warning: comparison between ‘cudaError_t’ {aka ‘enum cudaError’} and ‘enum <anonymous>’ [-Wenum-compare]
#   218 |         if (status != CUDNN_STATUS_SUCCESS)
#       |                    ^~
# ./src/dark_cuda.c: In function ‘cublas_check_error_extended’:
# ./src/dark_cuda.c:252:18: warning: comparison between ‘cudaError_t’ {aka ‘enum cudaError’} and ‘enum cudaError_enum’ [-Wenum-compare]
#   252 |       if (status != CUDA_SUCCESS)
#       |                  ^~
# At top level:
# ./src/dark_cuda.c:275:23: warning: ‘switchBlasHandle’ defined but not used [-Wunused-variable]
#   275 | static cublasHandle_t switchBlasHandle[16];
#       |                       ^~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:274:12: warning: ‘switchBlasInit’ defined but not used [-Wunused-variable]
#   274 | static int switchBlasInit[16] = { 0 };
#       |            ^~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1335:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#  1335 |                         size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#       |                                ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:79:5: warning: enumeration value ‘RELU6’ not handled in switch [-Wswitch]
#    79 |     switch(a){
#       |     ^~~~~~
# ./src/activations.c:79:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:310:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#   310 |     switch(a){
#       |     ^~~~~~
# ./src/activations.c:310:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:310:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:207:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#   207 |                 int out_index = id;
#       |                     ^~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/softmax_layer.c -o obj/softmax_layer.o
# ./src/softmax_layer.c: In function ‘forward_contrastive_layer’:
# ./src/softmax_layer.c:242:27: warning: variable ‘max_truth’ set but not used [-Wunused-but-set-variable]
#   242 |                     float max_truth = 0;
#       |                           ^~~~~~~~~
# ./src/softmax_layer.c:421:71: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t’ {aka ‘long unsigned int’} [-Wformat=]
#   421 |             printf(" Error: too large number of bboxes: contr_size = %d > max_contr_size  = %d \n", contr_size, max_contr_size);
#       |                                                                      ~^                             ~~~~~~~~~~
#       |                                                                       |                             |
#       |                                                                       int                           size_t {aka long unsigned int}
#       |                                                                      %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1399:43: warning: variable ‘r_scale’ set but not used [-Wunused-but-set-variable]
#  1399 |     float r1 = 0, r2 = 0, r3 = 0, r4 = 0, r_scale;
#       |                                           ^~~~~~~
# ./src/data.c: In function ‘fill_truth_detection’:
# ./src/data.c:431:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   431 |             sprintf(buff, "echo %s \"Wrong annotation: w = %f\" >> bad_label.list", labelpath, w);
#       |                                 ^~                                                  ~~~~~~~~~
# ./src/data.c:431:27: note: assuming directive output of 8 bytes
#   431 |             sprintf(buff, "echo %s \"Wrong annotation: w = %f\" >> bad_label.list", labelpath, w);
#       |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 52 and 4461 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:437:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   437 |             sprintf(buff, "echo %s \"Wrong annotation: h = %f\" >> bad_label.list", labelpath, h);
#       |                                 ^~                                                  ~~~~~~~~~
# ./src/data.c:437:27: note: assuming directive output of 8 bytes
#   437 |             sprintf(buff, "echo %s \"Wrong annotation: h = %f\" >> bad_label.list", labelpath, h);
#       |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 52 and 4461 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:424:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   424 |             sprintf(buff, "echo %s \"Wrong annotation: x = %f, y = %f\" >> bad_label.list", labelpath, x, y);
#       |                                 ^~                                                          ~~~~~~~~~
# ./src/data.c:424:27: note: assuming directive output of 8 bytes
#   424 |             sprintf(buff, "echo %s \"Wrong annotation: x = %f, y = %f\" >> bad_label.list", labelpath, x, y);
#       |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/data.c:424:27: note: assuming directive output of 8 bytes
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 61 and 4784 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:417:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   417 |             sprintf(buff, "echo %s \"Wrong annotation: x = 0 or y = 0\" >> bad_label.list", labelpath);
#       |                                 ^~                                                          ~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 59 and 4154 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:404:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   404 |             sprintf(buff, "echo %s \"Wrong annotation: class_id = %d. But class_id should be [from 0 to %d]\" >> bad_label.list", labelpath, id, (classes-1));
#       |                                 ^~                                                                                                ~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 95 and 4210 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘train_network_waitkey’:
# ./src/network.c:435:13: warning: unused variable ‘ema_period’ [-Wunused-variable]
#   435 |         int ema_period = (net.max_batches - ema_start_point - 1000) * (1.0 - net.ema_alpha);
#       |             ^~~~~~~~~~
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:660:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#   660 |         if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#       |                                          ^~~~~~~~~~~~~~~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/connected_layer.c -o obj/connected_layer.o
# ./src/connected_layer.c: In function ‘forward_connected_layer_gpu’:
# ./src/connected_layer.c:346:11: warning: unused variable ‘one’ [-Wunused-variable]
#   346 |     float one = 1;    // alpha[0], beta[0]
#       |           ^~~
# ./src/connected_layer.c:344:13: warning: unused variable ‘c’ [-Wunused-variable]
#   344 |     float * c = l.output_gpu;
#       |             ^
# ./src/connected_layer.c:343:13: warning: unused variable ‘b’ [-Wunused-variable]
#   343 |     float * b = l.weights_gpu;
#       |             ^
# ./src/connected_layer.c:342:13: warning: unused variable ‘a’ [-Wunused-variable]
#   342 |     float * a = state.input;
#       |             ^
# ./src/connected_layer.c:341:9: warning: unused variable ‘n’ [-Wunused-variable]
#   341 |     int n = l.outputs;
#       |         ^
# ./src/connected_layer.c:340:9: warning: unused variable ‘k’ [-Wunused-variable]
#   340 |     int k = l.inputs;
#       |         ^
# ./src/connected_layer.c:339:9: warning: unused variable ‘m’ [-Wunused-variable]
#   339 |     int m = l.batch;
#       |         ^
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1761:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#  1761 |         if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#       |                                          ^~~~~~~~~~~~~~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/parser.c: In function ‘save_implicit_weights’:
# ./src/parser.c:1893:9: warning: unused variable ‘i’ [-Wunused-variable]
#  1893 |     int i;
#       |         ^
# ./src/parser.c: In function ‘get_classes_multipliers’:
# ./src/parser.c:435:40: warning: argument 1 range [18446744071562067968, 18446744073709551615] exceeds maximum object size 9223372036854775807 [-Walloc-size-larger-than=]
#   435 |         classes_multipliers = (float *)calloc(classes_counters, sizeof(float));
#       |                                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from ./src/parser.c:3:
# /usr/include/stdlib.h:543:14: note: in a call to allocation function ‘calloc’ declared here
#   543 | extern void *calloc (size_t __nmemb, size_t __size)
#       |              ^~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘box_iou_kind’:
# ./src/box.c:154:5: warning: enumeration value ‘MSE’ not handled in switch [-Wswitch]
#   154 |     switch(iou_kind) {
#       |     ^~~~~~
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:898:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#   898 |                     float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#       |                           ^~~~~~~~~
# ./src/box.c:897:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#   897 |                     float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#       |                           ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#   248 |     char *base = "results/comp4_det_test_";
#       |           ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘train_detector’:
# ./src/detector.c:328:13: warning: variable ‘draw_precision’ set but not used [-Wunused-but-set-variable]
#   328 |         int draw_precision = 0;
#       |             ^~~~~~~~~~~~~~
# ./src/detector.c:64:11: warning: unused variable ‘avg_contrastive_acc’ [-Wunused-variable]
#    64 |     float avg_contrastive_acc = 0;
#       |           ^~~~~~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:585:21: warning: statement with no effect [-Wunused-value]
#   585 |                     for (k; buf[k + n] != '\0'; k++)
#       |                     ^~~
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:706:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#   706 |         int mkd2 = make_directory(buff2, 0777);
#       |             ^~~~
# ./src/detector.c:704:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#   704 |         int mkd = make_directory(buff, 0777);
#       |             ^~~
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1323:24: warning: variable ‘cur_prob’ set but not used [-Wunused-but-set-variable]
#  1323 |                 double cur_prob = 0;
#       |                        ^~~~~~~~
# ./src/detector.c:1344:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#  1344 |         float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#       |               ^~~~~~~~~~~~
# ./src/detector.c:1343:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#  1343 |         float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#       |               ^~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/layer.c -o obj/layer.o
# ./src/layer.c: In function ‘free_layer_custom’:
# ./src/layer.c:208:68: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#   208 |     if (l.delta_gpu && (l.optimized_memory < 1 || l.keep_delta_gpu && l.optimized_memory < 3)) cuda_free(l.delta_gpu), l.delta_gpu = NULL;
#       |                                                   ~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:190:13: warning: variable ‘draw_precision’ set but not used [-Wunused-but-set-variable]
#   190 |         int draw_precision = 0;
#       |             ^~~~~~~~~~~~~~
# ./src/classifier.c:146:9: warning: unused variable ‘count’ [-Wunused-variable]
#   146 |     int count = 0;
#       |         ^~~~~
# ./src/classifier.c:35:11: warning: unused variable ‘avg_contrastive_acc’ [-Wunused-variable]
#    35 |     float avg_contrastive_acc = 0;
#       |           ^~~~~~~~~~~~~~~~~~~
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:855:13: warning: unused variable ‘time’ [-Wunused-variable]
#   855 |     clock_t time;
#       |             ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# ./src/shortcut_layer.c: In function ‘make_shortcut_layer’:
# ./src/shortcut_layer.c:55:15: warning: unused variable ‘scale’ [-Wunused-variable]
#    55 |         float scale = sqrt(2. / l.nweights);
#       |               ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/representation_layer.c -o obj/representation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/demo.c -o obj/demo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/region_layer.c -o obj/region_layer.o
# ./src/region_layer.c: In function ‘resize_region_layer’:
# ./src/region_layer.c:63:9: warning: unused variable ‘old_h’ [-Wunused-variable]
#    63 |     int old_h = l->h;
#       |         ^~~~~
# ./src/region_layer.c:62:9: warning: unused variable ‘old_w’ [-Wunused-variable]
#    62 |     int old_w = l->w;
#       |         ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:67:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#    67 |     if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#       |                                      ^~~~~~~~~
#       |                                      |
#       |                                      float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/yolo_layer.c:74:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#    74 |     if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#       |                                      ^~~~~~~~
#       |                                      |
#       |                                      float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:105:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#   105 |         if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#       |                                          ^~~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/yolo_layer.c:114:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#   114 |         if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#       |                                          ^~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/yolo_layer.c: In function ‘process_batch’:
# ./src/yolo_layer.c:425:25: warning: variable ‘best_match_t’ set but not used [-Wunused-but-set-variable]
#   425 |                     int best_match_t = 0;
#       |                         ^~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘forward_yolo_layer’:
# ./src/yolo_layer.c:705:11: warning: unused variable ‘avg_anyobj’ [-Wunused-variable]
#   705 |     float avg_anyobj = 0;
#       |           ^~~~~~~~~~
# ./src/yolo_layer.c:704:11: warning: unused variable ‘avg_obj’ [-Wunused-variable]
#   704 |     float avg_obj = 0;
#       |           ^~~~~~~
# ./src/yolo_layer.c:703:11: warning: unused variable ‘avg_cat’ [-Wunused-variable]
#   703 |     float avg_cat = 0;
#       |           ^~~~~~~
# ./src/yolo_layer.c:702:11: warning: unused variable ‘recall75’ [-Wunused-variable]
#   702 |     float recall75 = 0;
#       |           ^~~~~~~~
# ./src/yolo_layer.c:701:11: warning: unused variable ‘recall’ [-Wunused-variable]
#   701 |     float recall = 0;
#       |           ^~~~~~
# ./src/yolo_layer.c:700:11: warning: unused variable ‘tot_ciou_loss’ [-Wunused-variable]
#   700 |     float tot_ciou_loss = 0;
#       |           ^~~~~~~~~~~~~
# ./src/yolo_layer.c:699:11: warning: unused variable ‘tot_diou_loss’ [-Wunused-variable]
#   699 |     float tot_diou_loss = 0;
#       |           ^~~~~~~~~~~~~
# ./src/yolo_layer.c:696:11: warning: unused variable ‘tot_ciou’ [-Wunused-variable]
#   696 |     float tot_ciou = 0;
#       |           ^~~~~~~~
# ./src/yolo_layer.c:695:11: warning: unused variable ‘tot_diou’ [-Wunused-variable]
#   695 |     float tot_diou = 0;
#       |           ^~~~~~~~
# ./src/yolo_layer.c:694:11: warning: unused variable ‘tot_giou’ [-Wunused-variable]
#   694 |     float tot_giou = 0;
#       |           ^~~~~~~~
# ./src/yolo_layer.c:666:12: warning: unused variable ‘n’ [-Wunused-variable]
#   666 |     int b, n;
#       |            ^
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gaussian_yolo_layer.c -o obj/gaussian_yolo_layer.o
# ./src/gaussian_yolo_layer.c: In function ‘make_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:70:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#    70 |     if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#       |                                      ^~~~~~~~~
#       |                                      |
#       |                                      float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/gaussian_yolo_layer.c:77:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#    77 |     if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#       |                                      ^~~~~~~~
#       |                                      |
#       |                                      float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/gaussian_yolo_layer.c: In function ‘resize_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:109:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#   109 |         if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#       |                                          ^~~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/gaussian_yolo_layer.c:118:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#   118 |         if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#       |                                          ^~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/sam_layer.c -o obj/sam_layer.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/network_kernels.cu -o obj/network_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/representation_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/gaussian_yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/conv_lstm_layer.o obj/scale_channels_layer.o obj/sam_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -L/usr/local/cudnn/lib64 -lcudnn -lstdc++

# %%
# !./darknet
# Out:
# usage: ./darknet <function>
